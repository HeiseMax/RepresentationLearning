# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

from sklearn.datasets import make_moons, make_s_curve

from Autoencoders import ConformalAutoencoder
from helper import load_optimizer_and_scheduler, save_optimizer_and_scheduler
from data import make_half_sphere

from torchvision.datasets import MNIST
from torchvision import transforms

random_state = 42
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class Encoder(nn.Module):
    def __init__(self, in_channels, latent_dim):
        super(Encoder, self).__init__()
        #input dim = 1, 32, 32
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, 8, 3, stride=2, padding=1),  # (8, 16, 16)
            nn.ReLU(True),
            nn.Conv2d(8, 16, 3, stride=2, padding=1),  # (16, 8, 8)
            nn.ReLU(True),
            nn.Conv2d(16, 32, 3, stride=2, padding=1),  # (32, 4, 4)
            nn.ReLU(True),
        )

        self.fc = nn.Sequential(
            nn.Linear(32 * 4 * 4, 64),  # Flatten to (64,)
            nn.ReLU(True),
            nn.Linear(64, latent_dim)  # Output latent dimension
        )
    
    def forward(self, x):
        x = self.conv(x)
        x = torch.flatten(x, start_dim=1)
        x = self.fc(x)
        return x

class Decoder(nn.Module):
    def __init__(self, out_channels, latent_dim):
        super(Decoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(latent_dim, 64),  # Input latent dimension
            nn.ReLU(True),
            nn.Linear(64, 32 * 4 * 4),  # Output size to reshape
            nn.ReLU(True),
        )
        self.deconv = nn.Sequential(
            nn.ConvTranspose2d(32, 16, 3, stride=2, padding=1, output_padding=1),  # (16, 6, 6)
            nn.ReLU(True),
            nn.ConvTranspose2d(16, 8, 3, stride=2, padding=1, output_padding=1),  # (8, 12, 12)
            nn.ReLU(True),
            nn.ConvTranspose2d(8, out_channels, 3, stride=2, padding=1, output_padding=1),  # (out_channels, 28, 28)
            nn.Sigmoid()  # For pixel values between 0 and 1
        )
    
    def forward(self, z):
        z = self.fc(z)
        z = torch.unflatten(z, 1, (32, 4, 4))  # Reshape to (32, 4, 4)
        z = self.deconv(z)
        return z

# class Encoder(nn.Module):
#     def __init__(self, input_dim, latent_dim):
#         super(Encoder, self).__init__()
#         self.fc = nn.Sequential(
#             # nn.Flatten(),
#             nn.Linear(28*28, 256),
#             nn.ReLU(True),
#             nn.Linear(256, 128),
#             nn.ReLU(True),
#             nn.Linear(128, 64),
#             nn.ReLU(True),
#             nn.Linear(64, 32)
#         )
    
#     def forward(self, x):
#         return self.fc(x)

# class Decoder(nn.Module):
#     def __init__(self, latent_dim, output_dim):
#         super(Decoder, self).__init__()
#         self.fc = nn.Sequential(
#             nn.Linear(32, 64),
#             nn.ReLU(True),
#             nn.Linear(64, 128),
#             nn.ReLU(True),
#             nn.Linear(128, 256),
#             nn.ReLU(True),
#             nn.Linear(256, 28*28),
#             nn.Sigmoid(),  # For pixel values between 0 and 1
#             # nn.Unflatten(1, (1, 28, 28))
#         )
    
#     def forward(self, z):
#         return self.fc(z)

# %%
mnist = MNIST(root='data', train=True, download=True, transform=None)
data, labels = mnist.data, mnist.targets
data = data[labels == 3][:3000]
labels = labels[labels == 3]
data = torch.tensor(data, dtype=torch.float32).to(device)
data = transforms.Resize((32, 32))(data)  # Resize to 32x32
data = data / 255.0  # Normalize the images to [0, 1]
data = data.view(data.size(0), 1, 32, 32)  # Add channel dimension
mnist_val = MNIST(root='data', train=False, download=True, transform=None)
val_data, val_labels = mnist_val.data, mnist_val.targets
val_data = val_data[val_labels == 3][:1000]
val_labels = val_labels[val_labels == 3]
val_data = torch.tensor(val_data, dtype=torch.float32).to(device)
val_data = transforms.Resize((32, 32))(val_data)  # Resize to 32x32
val_data = val_data / 255.0  # Normalize the images to [0, 1]
val_data = val_data.view(val_data.size(0), 1, 32, 32)  # Add channel dimension
# Out:
# /tmp/ipykernel_36502/315428273.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = torch.tensor(data, dtype=torch.float32).to(device)
# /tmp/ipykernel_36502/315428273.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   val_data = torch.tensor(val_data, dtype=torch.float32).to(device)

# %%
plt.imshow(data[0].view(32, 32).cpu().numpy(), cmap='gray')
plt.show()

# %%
# define model parameters
latent_dim = 32
input_dim = data.shape[1]
output_dim = data.shape[1]
batch_size = 256

in_channels = 1  # For grayscale images


train_dataloader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=False)

# %%
lambda_isos = np.logspace(-3, 3, 15)

# %%
from metrics import conformality_angle_loss

# %%
num_epochs = 600
# train same model multiple times to average results
num_models = 3

recon_errors = []
regularization_errors = []


for i, lambda_iso in enumerate(lambda_isos):
    recon_error = 0
    regularization = 0
    for j in range(num_models):
        print(f"Training model {j+1}/{num_models} with lambda_iso={lambda_iso:.3f}")

        encoder = Encoder(in_channels=in_channels, latent_dim=latent_dim).to(device)
        decoder = Decoder(latent_dim=latent_dim, out_channels=in_channels).to(device)
        model = ConformalAutoencoder(encoder, decoder, lambda_conf=lambda_iso).to(device)
        model.conformality_loss = conformality_angle_loss

        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)

        # Train the model
        model.train_model(train_dataloader, val_dataloader, batch_size=batch_size, epochs=num_epochs,
                          optimizer=optimizer, scheduler=scheduler, verbose=True)

        # Save the model and optimizer state
        model_path = f"models/conformal_autoencoder_mnist_vec/lambda_{lambda_iso:.3f}_model_{j+1}.pth"
        torch.save(model.state_dict(), model_path)
        print(f"Model {j+1}/{num_models} with lambda_iso={lambda_iso:.3f} trained and saved.")

        # evaluation
        model.eval()
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)
        
        recon_error += nn.MSELoss()(reconstruction, val_data).item()

        regularization += model.conformality_loss(model.decoder, encoded_data).item()
    
    recon_errors.append(recon_error/ num_models)
    regularization_errors.append(regularization/num_models)
# Out:
# Training model 1/3 with lambda_iso=0.001
# Epoch [100/600], Loss: 0.01012100, Reconstruction Loss: 0.01012100, Conformal Loss: 0.00000654
# Epoch [100/600], Validation Loss: 0.01062145, Reconstruction Loss: 0.01062144, Conformal Loss: 0.00000662
# Epoch [200/600], Loss: 0.00660302, Reconstruction Loss: 0.00660301, Conformal Loss: 0.00000892
# Epoch [200/600], Validation Loss: 0.00718328, Reconstruction Loss: 0.00718327, Conformal Loss: 0.00000908
# Epoch [300/600], Loss: 0.00573044, Reconstruction Loss: 0.00573044, Conformal Loss: 0.00000963
# Epoch [300/600], Validation Loss: 0.00642109, Reconstruction Loss: 0.00642108, Conformal Loss: 0.00000967
# Epoch [400/600], Loss: 0.00537577, Reconstruction Loss: 0.00537576, Conformal Loss: 0.00000995
# Epoch [400/600], Validation Loss: 0.00615744, Reconstruction Loss: 0.00615743, Conformal Loss: 0.00000986
# Epoch [500/600], Loss: 0.00521283, Reconstruction Loss: 0.00521282, Conformal Loss: 0.00000996
# Epoch [500/600], Validation Loss: 0.00602038, Reconstruction Loss: 0.00602037, Conformal Loss: 0.00001006
# Epoch [600/600], Loss: 0.00512571, Reconstruction Loss: 0.00512569, Conformal Loss: 0.00001015
# Epoch [600/600], Validation Loss: 0.00595618, Reconstruction Loss: 0.00595617, Conformal Loss: 0.00001028
# Model 1/3 with lambda_iso=0.001 trained and saved.
# Training model 2/3 with lambda_iso=0.001
# Epoch [100/600], Loss: 0.01210903, Reconstruction Loss: 0.01210902, Conformal Loss: 0.00001244
# Epoch [100/600], Validation Loss: 0.01245721, Reconstruction Loss: 0.01245719, Conformal Loss: 0.00001276
# Epoch [200/600], Loss: 0.00787700, Reconstruction Loss: 0.00787698, Conformal Loss: 0.00001838
# Epoch [200/600], Validation Loss: 0.00838678, Reconstruction Loss: 0.00838676, Conformal Loss: 0.00001923
# Epoch [300/600], Loss: 0.00677912, Reconstruction Loss: 0.00677910, Conformal Loss: 0.00001974
# Epoch [300/600], Validation Loss: 0.00730988, Reconstruction Loss: 0.00730986, Conformal Loss: 0.00001949
# Epoch [400/600], Loss: 0.00626937, Reconstruction Loss: 0.00626935, Conformal Loss: 0.00002011
# Epoch [400/600], Validation Loss: 0.00688472, Reconstruction Loss: 0.00688470, Conformal Loss: 0.00002045
# Epoch [500/600], Loss: 0.00607776, Reconstruction Loss: 0.00607774, Conformal Loss: 0.00002047
# Epoch [500/600], Validation Loss: 0.00671186, Reconstruction Loss: 0.00671184, Conformal Loss: 0.00002052
# Epoch [600/600], Loss: 0.00595667, Reconstruction Loss: 0.00595665, Conformal Loss: 0.00002059
# Epoch [600/600], Validation Loss: 0.00661426, Reconstruction Loss: 0.00661424, Conformal Loss: 0.00002088
# Model 2/3 with lambda_iso=0.001 trained and saved.
# Training model 3/3 with lambda_iso=0.001
# Epoch [100/600], Loss: 0.01141640, Reconstruction Loss: 0.01141639, Conformal Loss: 0.00000763
# Epoch [100/600], Validation Loss: 0.01147012, Reconstruction Loss: 0.01147011, Conformal Loss: 0.00000750
# Epoch [200/600], Loss: 0.00725035, Reconstruction Loss: 0.00725034, Conformal Loss: 0.00000931
# Epoch [200/600], Validation Loss: 0.00759188, Reconstruction Loss: 0.00759187, Conformal Loss: 0.00000938
# Epoch [300/600], Loss: 0.00630220, Reconstruction Loss: 0.00630219, Conformal Loss: 0.00000991
# Epoch [300/600], Validation Loss: 0.00678160, Reconstruction Loss: 0.00678159, Conformal Loss: 0.00000993
# Epoch [400/600], Loss: 0.00588861, Reconstruction Loss: 0.00588860, Conformal Loss: 0.00001002
# Epoch [400/600], Validation Loss: 0.00641159, Reconstruction Loss: 0.00641158, Conformal Loss: 0.00001039
# Epoch [500/600], Loss: 0.00568160, Reconstruction Loss: 0.00568159, Conformal Loss: 0.00001036
# Epoch [500/600], Validation Loss: 0.00623326, Reconstruction Loss: 0.00623325, Conformal Loss: 0.00001042
# Epoch [600/600], Loss: 0.00556062, Reconstruction Loss: 0.00556061, Conformal Loss: 0.00001039
# Epoch [600/600], Validation Loss: 0.00613858, Reconstruction Loss: 0.00613857, Conformal Loss: 0.00001040
# Model 3/3 with lambda_iso=0.001 trained and saved.
# Training model 1/3 with lambda_iso=0.003
# Epoch [100/600], Loss: 0.01112504, Reconstruction Loss: 0.01112502, Conformal Loss: 0.00000634
# Epoch [100/600], Validation Loss: 0.01143427, Reconstruction Loss: 0.01143425, Conformal Loss: 0.00000630
# Epoch [200/600], Loss: 0.00724273, Reconstruction Loss: 0.00724271, Conformal Loss: 0.00000818
# Epoch [200/600], Validation Loss: 0.00767533, Reconstruction Loss: 0.00767531, Conformal Loss: 0.00000826
# Epoch [300/600], Loss: 0.00622245, Reconstruction Loss: 0.00622243, Conformal Loss: 0.00000896
# Epoch [300/600], Validation Loss: 0.00678170, Reconstruction Loss: 0.00678167, Conformal Loss: 0.00000879
# Epoch [400/600], Loss: 0.00581777, Reconstruction Loss: 0.00581775, Conformal Loss: 0.00000923
# Epoch [400/600], Validation Loss: 0.00646238, Reconstruction Loss: 0.00646236, Conformal Loss: 0.00000923
# Epoch [500/600], Loss: 0.00563383, Reconstruction Loss: 0.00563381, Conformal Loss: 0.00000932
# Epoch [500/600], Validation Loss: 0.00630701, Reconstruction Loss: 0.00630699, Conformal Loss: 0.00000928
# Epoch [600/600], Loss: 0.00553585, Reconstruction Loss: 0.00553583, Conformal Loss: 0.00000955
# Epoch [600/600], Validation Loss: 0.00622490, Reconstruction Loss: 0.00622487, Conformal Loss: 0.00000948
# Model 1/3 with lambda_iso=0.003 trained and saved.
# Training model 2/3 with lambda_iso=0.003
# Epoch [100/600], Loss: 0.01284723, Reconstruction Loss: 0.01284722, Conformal Loss: 0.00000556
# Epoch [100/600], Validation Loss: 0.01293371, Reconstruction Loss: 0.01293369, Conformal Loss: 0.00000567
# Epoch [200/600], Loss: 0.00830059, Reconstruction Loss: 0.00830056, Conformal Loss: 0.00000790
# Epoch [200/600], Validation Loss: 0.00866177, Reconstruction Loss: 0.00866175, Conformal Loss: 0.00000802
# Epoch [300/600], Loss: 0.00707076, Reconstruction Loss: 0.00707073, Conformal Loss: 0.00000859
# Epoch [300/600], Validation Loss: 0.00752334, Reconstruction Loss: 0.00752332, Conformal Loss: 0.00000853
# Epoch [400/600], Loss: 0.00654758, Reconstruction Loss: 0.00654756, Conformal Loss: 0.00000888
# Epoch [400/600], Validation Loss: 0.00702472, Reconstruction Loss: 0.00702470, Conformal Loss: 0.00000875
# Epoch [500/600], Loss: 0.00632761, Reconstruction Loss: 0.00632759, Conformal Loss: 0.00000901
# Epoch [500/600], Validation Loss: 0.00682116, Reconstruction Loss: 0.00682113, Conformal Loss: 0.00000905
# Epoch [600/600], Loss: 0.00622645, Reconstruction Loss: 0.00622643, Conformal Loss: 0.00000901
# Epoch [600/600], Validation Loss: 0.00673257, Reconstruction Loss: 0.00673255, Conformal Loss: 0.00000919
# Model 2/3 with lambda_iso=0.003 trained and saved.
# Training model 3/3 with lambda_iso=0.003
# Epoch [100/600], Loss: 0.01023847, Reconstruction Loss: 0.01023843, Conformal Loss: 0.00001723
# Epoch [100/600], Validation Loss: 0.01054267, Reconstruction Loss: 0.01054262, Conformal Loss: 0.00001824
# Epoch [200/600], Loss: 0.00678835, Reconstruction Loss: 0.00678830, Conformal Loss: 0.00002089
# Epoch [200/600], Validation Loss: 0.00732345, Reconstruction Loss: 0.00732340, Conformal Loss: 0.00002130
# Epoch [300/600], Loss: 0.00584998, Reconstruction Loss: 0.00584992, Conformal Loss: 0.00002207
# Epoch [300/600], Validation Loss: 0.00643423, Reconstruction Loss: 0.00643417, Conformal Loss: 0.00002219
# Epoch [400/600], Loss: 0.00549645, Reconstruction Loss: 0.00549639, Conformal Loss: 0.00002263
# Epoch [400/600], Validation Loss: 0.00613548, Reconstruction Loss: 0.00613542, Conformal Loss: 0.00002283
# Epoch [500/600], Loss: 0.00531896, Reconstruction Loss: 0.00531890, Conformal Loss: 0.00002265
# Epoch [500/600], Validation Loss: 0.00598719, Reconstruction Loss: 0.00598713, Conformal Loss: 0.00002321
# Epoch [600/600], Loss: 0.00523504, Reconstruction Loss: 0.00523498, Conformal Loss: 0.00002288
# Epoch [600/600], Validation Loss: 0.00591628, Reconstruction Loss: 0.00591622, Conformal Loss: 0.00002300
# Model 3/3 with lambda_iso=0.003 trained and saved.
# Training model 1/3 with lambda_iso=0.007
# Epoch [100/600], Loss: 0.01687190, Reconstruction Loss: 0.01687185, Conformal Loss: 0.00000710
# Epoch [100/600], Validation Loss: 0.01690931, Reconstruction Loss: 0.01690925, Conformal Loss: 0.00000707
# Epoch [200/600], Loss: 0.01193457, Reconstruction Loss: 0.01193450, Conformal Loss: 0.00001020
# Epoch [200/600], Validation Loss: 0.01223239, Reconstruction Loss: 0.01223231, Conformal Loss: 0.00001039
# Epoch [300/600], Loss: 0.01055600, Reconstruction Loss: 0.01055592, Conformal Loss: 0.00001131
# Epoch [300/600], Validation Loss: 0.01093412, Reconstruction Loss: 0.01093404, Conformal Loss: 0.00001151
# Epoch [400/600], Loss: 0.00975352, Reconstruction Loss: 0.00975343, Conformal Loss: 0.00001232
# Epoch [400/600], Validation Loss: 0.01007442, Reconstruction Loss: 0.01007432, Conformal Loss: 0.00001258
# Epoch [500/600], Loss: 0.00925166, Reconstruction Loss: 0.00925157, Conformal Loss: 0.00001292
# Epoch [500/600], Validation Loss: 0.00955174, Reconstruction Loss: 0.00955165, Conformal Loss: 0.00001261
# Epoch [600/600], Loss: 0.00899342, Reconstruction Loss: 0.00899332, Conformal Loss: 0.00001325
# Epoch [600/600], Validation Loss: 0.00927849, Reconstruction Loss: 0.00927840, Conformal Loss: 0.00001307
# Model 1/3 with lambda_iso=0.007 trained and saved.
# Training model 2/3 with lambda_iso=0.007
# Epoch [100/600], Loss: 0.01031564, Reconstruction Loss: 0.01031558, Conformal Loss: 0.00000802
# Epoch [100/600], Validation Loss: 0.01047558, Reconstruction Loss: 0.01047553, Conformal Loss: 0.00000805
# Epoch [200/600], Loss: 0.00675970, Reconstruction Loss: 0.00675962, Conformal Loss: 0.00001026
# Epoch [200/600], Validation Loss: 0.00716774, Reconstruction Loss: 0.00716767, Conformal Loss: 0.00001027
# Epoch [300/600], Loss: 0.00598085, Reconstruction Loss: 0.00598077, Conformal Loss: 0.00001076
# Epoch [300/600], Validation Loss: 0.00651475, Reconstruction Loss: 0.00651467, Conformal Loss: 0.00001070
# Epoch [400/600], Loss: 0.00565843, Reconstruction Loss: 0.00565835, Conformal Loss: 0.00001115
# Epoch [400/600], Validation Loss: 0.00625876, Reconstruction Loss: 0.00625869, Conformal Loss: 0.00001095
# Epoch [500/600], Loss: 0.00549995, Reconstruction Loss: 0.00549987, Conformal Loss: 0.00001119
# Epoch [500/600], Validation Loss: 0.00613703, Reconstruction Loss: 0.00613695, Conformal Loss: 0.00001127
# Epoch [600/600], Loss: 0.00541040, Reconstruction Loss: 0.00541032, Conformal Loss: 0.00001140
# Epoch [600/600], Validation Loss: 0.00606805, Reconstruction Loss: 0.00606797, Conformal Loss: 0.00001135
# Model 2/3 with lambda_iso=0.007 trained and saved.
# Training model 3/3 with lambda_iso=0.007
# Epoch [100/600], Loss: 0.01111321, Reconstruction Loss: 0.01111316, Conformal Loss: 0.00000740
# Epoch [100/600], Validation Loss: 0.01144823, Reconstruction Loss: 0.01144817, Conformal Loss: 0.00000738
# Epoch [200/600], Loss: 0.00750940, Reconstruction Loss: 0.00750933, Conformal Loss: 0.00000940
# Epoch [200/600], Validation Loss: 0.00800484, Reconstruction Loss: 0.00800477, Conformal Loss: 0.00000957
# Epoch [300/600], Loss: 0.00629690, Reconstruction Loss: 0.00629682, Conformal Loss: 0.00001039
# Epoch [300/600], Validation Loss: 0.00683967, Reconstruction Loss: 0.00683960, Conformal Loss: 0.00001011
# Epoch [400/600], Loss: 0.00590035, Reconstruction Loss: 0.00590028, Conformal Loss: 0.00001077
# Epoch [400/600], Validation Loss: 0.00650437, Reconstruction Loss: 0.00650429, Conformal Loss: 0.00001071
# Epoch [500/600], Loss: 0.00571362, Reconstruction Loss: 0.00571355, Conformal Loss: 0.00001080
# Epoch [500/600], Validation Loss: 0.00635310, Reconstruction Loss: 0.00635302, Conformal Loss: 0.00001081
# Epoch [600/600], Loss: 0.00561155, Reconstruction Loss: 0.00561147, Conformal Loss: 0.00001107
# Epoch [600/600], Validation Loss: 0.00627445, Reconstruction Loss: 0.00627437, Conformal Loss: 0.00001084
# Model 3/3 with lambda_iso=0.007 trained and saved.
# Training model 1/3 with lambda_iso=0.019
# Epoch [100/600], Loss: 0.01120493, Reconstruction Loss: 0.01120484, Conformal Loss: 0.00000499
# Epoch [100/600], Validation Loss: 0.01139344, Reconstruction Loss: 0.01139335, Conformal Loss: 0.00000506
# Epoch [200/600], Loss: 0.00701158, Reconstruction Loss: 0.00701145, Conformal Loss: 0.00000689
# Epoch [200/600], Validation Loss: 0.00737992, Reconstruction Loss: 0.00737978, Conformal Loss: 0.00000692
# Epoch [300/600], Loss: 0.00611434, Reconstruction Loss: 0.00611420, Conformal Loss: 0.00000740
# Epoch [300/600], Validation Loss: 0.00661800, Reconstruction Loss: 0.00661786, Conformal Loss: 0.00000742
# Epoch [400/600], Loss: 0.00574844, Reconstruction Loss: 0.00574829, Conformal Loss: 0.00000769
# Epoch [400/600], Validation Loss: 0.00632688, Reconstruction Loss: 0.00632674, Conformal Loss: 0.00000766
# Epoch [500/600], Loss: 0.00558382, Reconstruction Loss: 0.00558367, Conformal Loss: 0.00000777
# Epoch [500/600], Validation Loss: 0.00618924, Reconstruction Loss: 0.00618909, Conformal Loss: 0.00000773
# Epoch [600/600], Loss: 0.00549907, Reconstruction Loss: 0.00549893, Conformal Loss: 0.00000773
# Epoch [600/600], Validation Loss: 0.00610940, Reconstruction Loss: 0.00610925, Conformal Loss: 0.00000778
# Model 1/3 with lambda_iso=0.019 trained and saved.
# Training model 2/3 with lambda_iso=0.019
# Epoch [100/600], Loss: 0.01061537, Reconstruction Loss: 0.01061514, Conformal Loss: 0.00001182
# Epoch [100/600], Validation Loss: 0.01077594, Reconstruction Loss: 0.01077571, Conformal Loss: 0.00001194
# Epoch [200/600], Loss: 0.00701234, Reconstruction Loss: 0.00701206, Conformal Loss: 0.00001466
# Epoch [200/600], Validation Loss: 0.00735858, Reconstruction Loss: 0.00735829, Conformal Loss: 0.00001500
# Epoch [300/600], Loss: 0.00618287, Reconstruction Loss: 0.00618258, Conformal Loss: 0.00001530
# Epoch [300/600], Validation Loss: 0.00665026, Reconstruction Loss: 0.00664996, Conformal Loss: 0.00001543
# Epoch [400/600], Loss: 0.00584744, Reconstruction Loss: 0.00584713, Conformal Loss: 0.00001591
# Epoch [400/600], Validation Loss: 0.00637077, Reconstruction Loss: 0.00637045, Conformal Loss: 0.00001622
# Epoch [500/600], Loss: 0.00567009, Reconstruction Loss: 0.00566978, Conformal Loss: 0.00001620
# Epoch [500/600], Validation Loss: 0.00622091, Reconstruction Loss: 0.00622059, Conformal Loss: 0.00001662
# Epoch [600/600], Loss: 0.00557829, Reconstruction Loss: 0.00557798, Conformal Loss: 0.00001600
# Epoch [600/600], Validation Loss: 0.00615396, Reconstruction Loss: 0.00615364, Conformal Loss: 0.00001645
# Model 2/3 with lambda_iso=0.019 trained and saved.
# Training model 3/3 with lambda_iso=0.019
# Epoch [100/600], Loss: 0.01354579, Reconstruction Loss: 0.01354563, Conformal Loss: 0.00000858
# Epoch [100/600], Validation Loss: 0.01360817, Reconstruction Loss: 0.01360800, Conformal Loss: 0.00000854
# Epoch [200/600], Loss: 0.00910612, Reconstruction Loss: 0.00910591, Conformal Loss: 0.00001112
# Epoch [200/600], Validation Loss: 0.00960046, Reconstruction Loss: 0.00960025, Conformal Loss: 0.00001107
# Epoch [300/600], Loss: 0.00766551, Reconstruction Loss: 0.00766527, Conformal Loss: 0.00001230
# Epoch [300/600], Validation Loss: 0.00821434, Reconstruction Loss: 0.00821410, Conformal Loss: 0.00001238
# Epoch [400/600], Loss: 0.00698470, Reconstruction Loss: 0.00698444, Conformal Loss: 0.00001323
# Epoch [400/600], Validation Loss: 0.00751486, Reconstruction Loss: 0.00751461, Conformal Loss: 0.00001320
# Epoch [500/600], Loss: 0.00670395, Reconstruction Loss: 0.00670369, Conformal Loss: 0.00001355
# Epoch [500/600], Validation Loss: 0.00724165, Reconstruction Loss: 0.00724139, Conformal Loss: 0.00001343
# Epoch [600/600], Loss: 0.00656531, Reconstruction Loss: 0.00656504, Conformal Loss: 0.00001381
# Epoch [600/600], Validation Loss: 0.00712493, Reconstruction Loss: 0.00712467, Conformal Loss: 0.00001378
# Model 3/3 with lambda_iso=0.019 trained and saved.
# Training model 1/3 with lambda_iso=0.052
# Epoch [100/600], Loss: 0.01047407, Reconstruction Loss: 0.01047375, Conformal Loss: 0.00000610
# Epoch [100/600], Validation Loss: 0.01083588, Reconstruction Loss: 0.01083557, Conformal Loss: 0.00000613
# Epoch [200/600], Loss: 0.00721201, Reconstruction Loss: 0.00721163, Conformal Loss: 0.00000727
# Epoch [200/600], Validation Loss: 0.00770447, Reconstruction Loss: 0.00770409, Conformal Loss: 0.00000741
# Epoch [300/600], Loss: 0.00629046, Reconstruction Loss: 0.00629005, Conformal Loss: 0.00000783
# Epoch [300/600], Validation Loss: 0.00693540, Reconstruction Loss: 0.00693499, Conformal Loss: 0.00000795
# Epoch [400/600], Loss: 0.00590172, Reconstruction Loss: 0.00590130, Conformal Loss: 0.00000815
# Epoch [400/600], Validation Loss: 0.00660120, Reconstruction Loss: 0.00660078, Conformal Loss: 0.00000806
# Epoch [500/600], Loss: 0.00571349, Reconstruction Loss: 0.00571306, Conformal Loss: 0.00000837
# Epoch [500/600], Validation Loss: 0.00643304, Reconstruction Loss: 0.00643261, Conformal Loss: 0.00000829
# Epoch [600/600], Loss: 0.00561111, Reconstruction Loss: 0.00561067, Conformal Loss: 0.00000848
# Epoch [600/600], Validation Loss: 0.00634570, Reconstruction Loss: 0.00634526, Conformal Loss: 0.00000855
# Model 1/3 with lambda_iso=0.052 trained and saved.
# Training model 2/3 with lambda_iso=0.052
# Epoch [100/600], Loss: 0.00959828, Reconstruction Loss: 0.00959767, Conformal Loss: 0.00001176
# Epoch [100/600], Validation Loss: 0.00989331, Reconstruction Loss: 0.00989269, Conformal Loss: 0.00001197
# Epoch [200/600], Loss: 0.00624392, Reconstruction Loss: 0.00624307, Conformal Loss: 0.00001637
# Epoch [200/600], Validation Loss: 0.00664510, Reconstruction Loss: 0.00664426, Conformal Loss: 0.00001633
# Epoch [300/600], Loss: 0.00546953, Reconstruction Loss: 0.00546863, Conformal Loss: 0.00001734
# Epoch [300/600], Validation Loss: 0.00604776, Reconstruction Loss: 0.00604685, Conformal Loss: 0.00001750
# Epoch [400/600], Loss: 0.00514114, Reconstruction Loss: 0.00514021, Conformal Loss: 0.00001790
# Epoch [400/600], Validation Loss: 0.00577272, Reconstruction Loss: 0.00577179, Conformal Loss: 0.00001796
# Epoch [500/600], Loss: 0.00496804, Reconstruction Loss: 0.00496709, Conformal Loss: 0.00001833
# Epoch [500/600], Validation Loss: 0.00563171, Reconstruction Loss: 0.00563078, Conformal Loss: 0.00001799
# Epoch [600/600], Loss: 0.00488183, Reconstruction Loss: 0.00488087, Conformal Loss: 0.00001859
# Epoch [600/600], Validation Loss: 0.00556156, Reconstruction Loss: 0.00556060, Conformal Loss: 0.00001840
# Model 2/3 with lambda_iso=0.052 trained and saved.
# Training model 3/3 with lambda_iso=0.052
# Epoch [100/600], Loss: 0.01266926, Reconstruction Loss: 0.01266909, Conformal Loss: 0.00000323
# Epoch [100/600], Validation Loss: 0.01326725, Reconstruction Loss: 0.01326708, Conformal Loss: 0.00000324
# Epoch [200/600], Loss: 0.00759040, Reconstruction Loss: 0.00759011, Conformal Loss: 0.00000551
# Epoch [200/600], Validation Loss: 0.00821716, Reconstruction Loss: 0.00821687, Conformal Loss: 0.00000560
# Epoch [300/600], Loss: 0.00647965, Reconstruction Loss: 0.00647933, Conformal Loss: 0.00000613
# Epoch [300/600], Validation Loss: 0.00716299, Reconstruction Loss: 0.00716267, Conformal Loss: 0.00000616
# Epoch [400/600], Loss: 0.00612823, Reconstruction Loss: 0.00612790, Conformal Loss: 0.00000626
# Epoch [400/600], Validation Loss: 0.00686471, Reconstruction Loss: 0.00686438, Conformal Loss: 0.00000632
# Epoch [500/600], Loss: 0.00596804, Reconstruction Loss: 0.00596771, Conformal Loss: 0.00000630
# Epoch [500/600], Validation Loss: 0.00673513, Reconstruction Loss: 0.00673481, Conformal Loss: 0.00000633
# Epoch [600/600], Loss: 0.00587921, Reconstruction Loss: 0.00587887, Conformal Loss: 0.00000644
# Epoch [600/600], Validation Loss: 0.00667253, Reconstruction Loss: 0.00667220, Conformal Loss: 0.00000635
# Model 3/3 with lambda_iso=0.052 trained and saved.
# Training model 1/3 with lambda_iso=0.139
# Epoch [100/600], Loss: 0.00989127, Reconstruction Loss: 0.00988982, Conformal Loss: 0.00001039
# Epoch [100/600], Validation Loss: 0.01038707, Reconstruction Loss: 0.01038564, Conformal Loss: 0.00001032
# Epoch [200/600], Loss: 0.00672326, Reconstruction Loss: 0.00672151, Conformal Loss: 0.00001262
# Epoch [200/600], Validation Loss: 0.00721290, Reconstruction Loss: 0.00721120, Conformal Loss: 0.00001228
# Epoch [300/600], Loss: 0.00589079, Reconstruction Loss: 0.00588898, Conformal Loss: 0.00001299
# Epoch [300/600], Validation Loss: 0.00642899, Reconstruction Loss: 0.00642715, Conformal Loss: 0.00001322
# Epoch [400/600], Loss: 0.00552971, Reconstruction Loss: 0.00552788, Conformal Loss: 0.00001320
# Epoch [400/600], Validation Loss: 0.00613679, Reconstruction Loss: 0.00613496, Conformal Loss: 0.00001315
# Epoch [500/600], Loss: 0.00535338, Reconstruction Loss: 0.00535153, Conformal Loss: 0.00001330
# Epoch [500/600], Validation Loss: 0.00599344, Reconstruction Loss: 0.00599157, Conformal Loss: 0.00001348
# Epoch [600/600], Loss: 0.00525824, Reconstruction Loss: 0.00525640, Conformal Loss: 0.00001328
# Epoch [600/600], Validation Loss: 0.00592190, Reconstruction Loss: 0.00592006, Conformal Loss: 0.00001328
# Model 1/3 with lambda_iso=0.139 trained and saved.
# Training model 2/3 with lambda_iso=0.139
# Epoch [100/600], Loss: 0.01056631, Reconstruction Loss: 0.01056450, Conformal Loss: 0.00001302
# Epoch [100/600], Validation Loss: 0.01088883, Reconstruction Loss: 0.01088699, Conformal Loss: 0.00001322
# Epoch [200/600], Loss: 0.00684540, Reconstruction Loss: 0.00684305, Conformal Loss: 0.00001689
# Epoch [200/600], Validation Loss: 0.00730994, Reconstruction Loss: 0.00730756, Conformal Loss: 0.00001709
# Epoch [300/600], Loss: 0.00607518, Reconstruction Loss: 0.00607267, Conformal Loss: 0.00001804
# Epoch [300/600], Validation Loss: 0.00664350, Reconstruction Loss: 0.00664102, Conformal Loss: 0.00001781
# Epoch [400/600], Loss: 0.00574452, Reconstruction Loss: 0.00574201, Conformal Loss: 0.00001807
# Epoch [400/600], Validation Loss: 0.00637554, Reconstruction Loss: 0.00637301, Conformal Loss: 0.00001827
# Epoch [500/600], Loss: 0.00557733, Reconstruction Loss: 0.00557477, Conformal Loss: 0.00001839
# Epoch [500/600], Validation Loss: 0.00623589, Reconstruction Loss: 0.00623330, Conformal Loss: 0.00001860
# Epoch [600/600], Loss: 0.00547646, Reconstruction Loss: 0.00547387, Conformal Loss: 0.00001859
# Epoch [600/600], Validation Loss: 0.00615793, Reconstruction Loss: 0.00615530, Conformal Loss: 0.00001891
# Model 2/3 with lambda_iso=0.139 trained and saved.
# Training model 3/3 with lambda_iso=0.139
# Epoch [100/600], Loss: 0.00888713, Reconstruction Loss: 0.00888606, Conformal Loss: 0.00000765
# Epoch [100/600], Validation Loss: 0.00921215, Reconstruction Loss: 0.00921108, Conformal Loss: 0.00000768
# Epoch [200/600], Loss: 0.00635365, Reconstruction Loss: 0.00635238, Conformal Loss: 0.00000914
# Epoch [200/600], Validation Loss: 0.00683956, Reconstruction Loss: 0.00683829, Conformal Loss: 0.00000919
# Epoch [300/600], Loss: 0.00567327, Reconstruction Loss: 0.00567194, Conformal Loss: 0.00000962
# Epoch [300/600], Validation Loss: 0.00627203, Reconstruction Loss: 0.00627068, Conformal Loss: 0.00000973
# Epoch [400/600], Loss: 0.00537119, Reconstruction Loss: 0.00536982, Conformal Loss: 0.00000982
# Epoch [400/600], Validation Loss: 0.00602526, Reconstruction Loss: 0.00602391, Conformal Loss: 0.00000974
# Epoch [500/600], Loss: 0.00520808, Reconstruction Loss: 0.00520671, Conformal Loss: 0.00000987
# Epoch [500/600], Validation Loss: 0.00590186, Reconstruction Loss: 0.00590052, Conformal Loss: 0.00000967
# Epoch [600/600], Loss: 0.00513375, Reconstruction Loss: 0.00513236, Conformal Loss: 0.00000997
# Epoch [600/600], Validation Loss: 0.00583188, Reconstruction Loss: 0.00583053, Conformal Loss: 0.00000970
# Model 3/3 with lambda_iso=0.139 trained and saved.
# Training model 1/3 with lambda_iso=0.373
# Epoch [100/600], Loss: 0.01073820, Reconstruction Loss: 0.01073689, Conformal Loss: 0.00000352
# Epoch [100/600], Validation Loss: 0.01123702, Reconstruction Loss: 0.01123569, Conformal Loss: 0.00000359
# Epoch [200/600], Loss: 0.00701140, Reconstruction Loss: 0.00700966, Conformal Loss: 0.00000468
# Epoch [200/600], Validation Loss: 0.00754424, Reconstruction Loss: 0.00754251, Conformal Loss: 0.00000465
# Epoch [300/600], Loss: 0.00610419, Reconstruction Loss: 0.00610233, Conformal Loss: 0.00000499
# Epoch [300/600], Validation Loss: 0.00679564, Reconstruction Loss: 0.00679378, Conformal Loss: 0.00000498
# Epoch [400/600], Loss: 0.00577734, Reconstruction Loss: 0.00577545, Conformal Loss: 0.00000507
# Epoch [400/600], Validation Loss: 0.00654857, Reconstruction Loss: 0.00654668, Conformal Loss: 0.00000506
# Epoch [500/600], Loss: 0.00562598, Reconstruction Loss: 0.00562407, Conformal Loss: 0.00000513
# Epoch [500/600], Validation Loss: 0.00642379, Reconstruction Loss: 0.00642189, Conformal Loss: 0.00000511
# Epoch [600/600], Loss: 0.00554631, Reconstruction Loss: 0.00554437, Conformal Loss: 0.00000521
# Epoch [600/600], Validation Loss: 0.00636538, Reconstruction Loss: 0.00636344, Conformal Loss: 0.00000521
# Model 1/3 with lambda_iso=0.373 trained and saved.
# Training model 2/3 with lambda_iso=0.373
# Epoch [100/600], Loss: 0.00965136, Reconstruction Loss: 0.00964796, Conformal Loss: 0.00000914
# Epoch [100/600], Validation Loss: 0.00971168, Reconstruction Loss: 0.00970825, Conformal Loss: 0.00000918
# Epoch [200/600], Loss: 0.00652483, Reconstruction Loss: 0.00652065, Conformal Loss: 0.00001121
# Epoch [200/600], Validation Loss: 0.00689215, Reconstruction Loss: 0.00688803, Conformal Loss: 0.00001104
# Epoch [300/600], Loss: 0.00578489, Reconstruction Loss: 0.00578053, Conformal Loss: 0.00001169
# Epoch [300/600], Validation Loss: 0.00631007, Reconstruction Loss: 0.00630576, Conformal Loss: 0.00001158
# Epoch [400/600], Loss: 0.00541716, Reconstruction Loss: 0.00541273, Conformal Loss: 0.00001187
# Epoch [400/600], Validation Loss: 0.00602485, Reconstruction Loss: 0.00602041, Conformal Loss: 0.00001190
# Epoch [500/600], Loss: 0.00523552, Reconstruction Loss: 0.00523102, Conformal Loss: 0.00001207
# Epoch [500/600], Validation Loss: 0.00587137, Reconstruction Loss: 0.00586686, Conformal Loss: 0.00001210
# Epoch [600/600], Loss: 0.00514155, Reconstruction Loss: 0.00513707, Conformal Loss: 0.00001204
# Epoch [600/600], Validation Loss: 0.00579567, Reconstruction Loss: 0.00579112, Conformal Loss: 0.00001222
# Model 2/3 with lambda_iso=0.373 trained and saved.
# Training model 3/3 with lambda_iso=0.373
# Epoch [100/600], Loss: 0.01167034, Reconstruction Loss: 0.01166850, Conformal Loss: 0.00000494
# Epoch [100/600], Validation Loss: 0.01202756, Reconstruction Loss: 0.01202566, Conformal Loss: 0.00000511
# Epoch [200/600], Loss: 0.00743135, Reconstruction Loss: 0.00742891, Conformal Loss: 0.00000655
# Epoch [200/600], Validation Loss: 0.00796389, Reconstruction Loss: 0.00796146, Conformal Loss: 0.00000654
# Epoch [300/600], Loss: 0.00649503, Reconstruction Loss: 0.00649246, Conformal Loss: 0.00000688
# Epoch [300/600], Validation Loss: 0.00710467, Reconstruction Loss: 0.00710210, Conformal Loss: 0.00000689
# Epoch [400/600], Loss: 0.00611984, Reconstruction Loss: 0.00611721, Conformal Loss: 0.00000704
# Epoch [400/600], Validation Loss: 0.00681067, Reconstruction Loss: 0.00680802, Conformal Loss: 0.00000711
# Epoch [500/600], Loss: 0.00593300, Reconstruction Loss: 0.00593038, Conformal Loss: 0.00000704
# Epoch [500/600], Validation Loss: 0.00666139, Reconstruction Loss: 0.00665874, Conformal Loss: 0.00000710
# Epoch [600/600], Loss: 0.00583373, Reconstruction Loss: 0.00583105, Conformal Loss: 0.00000718
# Epoch [600/600], Validation Loss: 0.00656998, Reconstruction Loss: 0.00656727, Conformal Loss: 0.00000727
# Model 3/3 with lambda_iso=0.373 trained and saved.
# Training model 1/3 with lambda_iso=1.000
# Epoch [100/600], Loss: 0.01252781, Reconstruction Loss: 0.01251157, Conformal Loss: 0.00001624
# Epoch [100/600], Validation Loss: 0.01284082, Reconstruction Loss: 0.01282436, Conformal Loss: 0.00001647
# Epoch [200/600], Loss: 0.00880862, Reconstruction Loss: 0.00878841, Conformal Loss: 0.00002021
# Epoch [200/600], Validation Loss: 0.00929983, Reconstruction Loss: 0.00927980, Conformal Loss: 0.00002003
# Epoch [300/600], Loss: 0.00764051, Reconstruction Loss: 0.00761867, Conformal Loss: 0.00002184
# Epoch [300/600], Validation Loss: 0.00822150, Reconstruction Loss: 0.00819930, Conformal Loss: 0.00002220
# Epoch [400/600], Loss: 0.00708302, Reconstruction Loss: 0.00706019, Conformal Loss: 0.00002283
# Epoch [400/600], Validation Loss: 0.00765132, Reconstruction Loss: 0.00762862, Conformal Loss: 0.00002270
# Epoch [500/600], Loss: 0.00679507, Reconstruction Loss: 0.00677205, Conformal Loss: 0.00002302
# Epoch [500/600], Validation Loss: 0.00738529, Reconstruction Loss: 0.00736175, Conformal Loss: 0.00002353
# Epoch [600/600], Loss: 0.00667678, Reconstruction Loss: 0.00665433, Conformal Loss: 0.00002244
# Epoch [600/600], Validation Loss: 0.00727556, Reconstruction Loss: 0.00725264, Conformal Loss: 0.00002292
# Model 1/3 with lambda_iso=1.000 trained and saved.
# Training model 2/3 with lambda_iso=1.000
# Epoch [100/600], Loss: 0.01135959, Reconstruction Loss: 0.01135592, Conformal Loss: 0.00000368
# Epoch [100/600], Validation Loss: 0.01161466, Reconstruction Loss: 0.01161096, Conformal Loss: 0.00000370
# Epoch [200/600], Loss: 0.00720100, Reconstruction Loss: 0.00719571, Conformal Loss: 0.00000529
# Epoch [200/600], Validation Loss: 0.00763951, Reconstruction Loss: 0.00763415, Conformal Loss: 0.00000535
# Epoch [300/600], Loss: 0.00615855, Reconstruction Loss: 0.00615278, Conformal Loss: 0.00000577
# Epoch [300/600], Validation Loss: 0.00673947, Reconstruction Loss: 0.00673368, Conformal Loss: 0.00000580
# Epoch [400/600], Loss: 0.00580070, Reconstruction Loss: 0.00579474, Conformal Loss: 0.00000596
# Epoch [400/600], Validation Loss: 0.00646015, Reconstruction Loss: 0.00645406, Conformal Loss: 0.00000609
# Epoch [500/600], Loss: 0.00564063, Reconstruction Loss: 0.00563462, Conformal Loss: 0.00000600
# Epoch [500/600], Validation Loss: 0.00633895, Reconstruction Loss: 0.00633294, Conformal Loss: 0.00000601
# Epoch [600/600], Loss: 0.00555089, Reconstruction Loss: 0.00554494, Conformal Loss: 0.00000595
# Epoch [600/600], Validation Loss: 0.00627696, Reconstruction Loss: 0.00627102, Conformal Loss: 0.00000595
# Model 2/3 with lambda_iso=1.000 trained and saved.
# Training model 3/3 with lambda_iso=1.000
# Epoch [100/600], Loss: 0.01232114, Reconstruction Loss: 0.01231916, Conformal Loss: 0.00000199
# Epoch [100/600], Validation Loss: 0.01258343, Reconstruction Loss: 0.01258141, Conformal Loss: 0.00000201
# Epoch [200/600], Loss: 0.00821926, Reconstruction Loss: 0.00821655, Conformal Loss: 0.00000271
# Epoch [200/600], Validation Loss: 0.00879578, Reconstruction Loss: 0.00879304, Conformal Loss: 0.00000274
# Epoch [300/600], Loss: 0.00700116, Reconstruction Loss: 0.00699824, Conformal Loss: 0.00000293
# Epoch [300/600], Validation Loss: 0.00761201, Reconstruction Loss: 0.00760913, Conformal Loss: 0.00000288
# Epoch [400/600], Loss: 0.00655249, Reconstruction Loss: 0.00654951, Conformal Loss: 0.00000299
# Epoch [400/600], Validation Loss: 0.00724054, Reconstruction Loss: 0.00723753, Conformal Loss: 0.00000301
# Epoch [500/600], Loss: 0.00634955, Reconstruction Loss: 0.00634654, Conformal Loss: 0.00000300
# Epoch [500/600], Validation Loss: 0.00706768, Reconstruction Loss: 0.00706461, Conformal Loss: 0.00000307
# Epoch [600/600], Loss: 0.00625408, Reconstruction Loss: 0.00625107, Conformal Loss: 0.00000301
# Epoch [600/600], Validation Loss: 0.00698306, Reconstruction Loss: 0.00698000, Conformal Loss: 0.00000307
# Model 3/3 with lambda_iso=1.000 trained and saved.
# Training model 1/3 with lambda_iso=2.683
# Epoch [100/600], Loss: 0.01059291, Reconstruction Loss: 0.01057048, Conformal Loss: 0.00000836
# Epoch [100/600], Validation Loss: 0.01073736, Reconstruction Loss: 0.01071473, Conformal Loss: 0.00000843
# Epoch [200/600], Loss: 0.00683974, Reconstruction Loss: 0.00681475, Conformal Loss: 0.00000931
# Epoch [200/600], Validation Loss: 0.00731700, Reconstruction Loss: 0.00729203, Conformal Loss: 0.00000931
# Epoch [300/600], Loss: 0.00592288, Reconstruction Loss: 0.00589805, Conformal Loss: 0.00000925
# Epoch [300/600], Validation Loss: 0.00652341, Reconstruction Loss: 0.00649829, Conformal Loss: 0.00000937
# Epoch [400/600], Loss: 0.00556354, Reconstruction Loss: 0.00553921, Conformal Loss: 0.00000907
# Epoch [400/600], Validation Loss: 0.00623767, Reconstruction Loss: 0.00621316, Conformal Loss: 0.00000914
# Epoch [500/600], Loss: 0.00538537, Reconstruction Loss: 0.00536183, Conformal Loss: 0.00000877
# Epoch [500/600], Validation Loss: 0.00609248, Reconstruction Loss: 0.00606807, Conformal Loss: 0.00000910
# Epoch [600/600], Loss: 0.00530135, Reconstruction Loss: 0.00527773, Conformal Loss: 0.00000880
# Epoch [600/600], Validation Loss: 0.00602192, Reconstruction Loss: 0.00599816, Conformal Loss: 0.00000886
# Model 1/3 with lambda_iso=2.683 trained and saved.
# Training model 2/3 with lambda_iso=2.683
# Epoch [100/600], Loss: 0.01497384, Reconstruction Loss: 0.01495722, Conformal Loss: 0.00000619
# Epoch [100/600], Validation Loss: 0.01496664, Reconstruction Loss: 0.01494947, Conformal Loss: 0.00000640
# Epoch [200/600], Loss: 0.01055259, Reconstruction Loss: 0.01053387, Conformal Loss: 0.00000698
# Epoch [200/600], Validation Loss: 0.01099767, Reconstruction Loss: 0.01097868, Conformal Loss: 0.00000708
# Epoch [300/600], Loss: 0.00913507, Reconstruction Loss: 0.00911588, Conformal Loss: 0.00000715
# Epoch [300/600], Validation Loss: 0.00984492, Reconstruction Loss: 0.00982570, Conformal Loss: 0.00000716
# Epoch [400/600], Loss: 0.00835254, Reconstruction Loss: 0.00833302, Conformal Loss: 0.00000728
# Epoch [400/600], Validation Loss: 0.00907306, Reconstruction Loss: 0.00905360, Conformal Loss: 0.00000725
# Epoch [500/600], Loss: 0.00801053, Reconstruction Loss: 0.00799098, Conformal Loss: 0.00000729
# Epoch [500/600], Validation Loss: 0.00876644, Reconstruction Loss: 0.00874664, Conformal Loss: 0.00000738
# Epoch [600/600], Loss: 0.00784317, Reconstruction Loss: 0.00782369, Conformal Loss: 0.00000726
# Epoch [600/600], Validation Loss: 0.00861695, Reconstruction Loss: 0.00859723, Conformal Loss: 0.00000735
# Model 2/3 with lambda_iso=2.683 trained and saved.
# Training model 3/3 with lambda_iso=2.683
# Epoch [100/600], Loss: 0.01285503, Reconstruction Loss: 0.01284328, Conformal Loss: 0.00000438
# Epoch [100/600], Validation Loss: 0.01303479, Reconstruction Loss: 0.01302291, Conformal Loss: 0.00000443
# Epoch [200/600], Loss: 0.00837268, Reconstruction Loss: 0.00835694, Conformal Loss: 0.00000587
# Epoch [200/600], Validation Loss: 0.00886875, Reconstruction Loss: 0.00885335, Conformal Loss: 0.00000574
# Epoch [300/600], Loss: 0.00712168, Reconstruction Loss: 0.00710518, Conformal Loss: 0.00000615
# Epoch [300/600], Validation Loss: 0.00761881, Reconstruction Loss: 0.00760230, Conformal Loss: 0.00000615
# Epoch [400/600], Loss: 0.00659653, Reconstruction Loss: 0.00657996, Conformal Loss: 0.00000618
# Epoch [400/600], Validation Loss: 0.00713542, Reconstruction Loss: 0.00711882, Conformal Loss: 0.00000619
# Epoch [500/600], Loss: 0.00638206, Reconstruction Loss: 0.00636539, Conformal Loss: 0.00000621
# Epoch [500/600], Validation Loss: 0.00694444, Reconstruction Loss: 0.00692797, Conformal Loss: 0.00000614
# Epoch [600/600], Loss: 0.00626140, Reconstruction Loss: 0.00624487, Conformal Loss: 0.00000616
# Epoch [600/600], Validation Loss: 0.00684690, Reconstruction Loss: 0.00683024, Conformal Loss: 0.00000621
# Model 3/3 with lambda_iso=2.683 trained and saved.
# Training model 1/3 with lambda_iso=7.197
# Epoch [100/600], Loss: 0.01050311, Reconstruction Loss: 0.01043995, Conformal Loss: 0.00000878
# Epoch [100/600], Validation Loss: 0.01091488, Reconstruction Loss: 0.01085133, Conformal Loss: 0.00000883
# Epoch [200/600], Loss: 0.00730320, Reconstruction Loss: 0.00724444, Conformal Loss: 0.00000816
# Epoch [200/600], Validation Loss: 0.00791187, Reconstruction Loss: 0.00785076, Conformal Loss: 0.00000849
# Epoch [300/600], Loss: 0.00634078, Reconstruction Loss: 0.00628623, Conformal Loss: 0.00000758
# Epoch [300/600], Validation Loss: 0.00702226, Reconstruction Loss: 0.00696486, Conformal Loss: 0.00000797
# Epoch [400/600], Loss: 0.00595867, Reconstruction Loss: 0.00590636, Conformal Loss: 0.00000727
# Epoch [400/600], Validation Loss: 0.00668501, Reconstruction Loss: 0.00663292, Conformal Loss: 0.00000724
# Epoch [500/600], Loss: 0.00576613, Reconstruction Loss: 0.00571589, Conformal Loss: 0.00000698
# Epoch [500/600], Validation Loss: 0.00652962, Reconstruction Loss: 0.00647896, Conformal Loss: 0.00000704
# Epoch [600/600], Loss: 0.00567043, Reconstruction Loss: 0.00562104, Conformal Loss: 0.00000686
# Epoch [600/600], Validation Loss: 0.00644577, Reconstruction Loss: 0.00639617, Conformal Loss: 0.00000689
# Model 1/3 with lambda_iso=7.197 trained and saved.
# Training model 2/3 with lambda_iso=7.197
# Epoch [100/600], Loss: 0.00941613, Reconstruction Loss: 0.00937355, Conformal Loss: 0.00000592
# Epoch [100/600], Validation Loss: 0.00991842, Reconstruction Loss: 0.00987679, Conformal Loss: 0.00000578
# Epoch [200/600], Loss: 0.00674390, Reconstruction Loss: 0.00669987, Conformal Loss: 0.00000612
# Epoch [200/600], Validation Loss: 0.00731930, Reconstruction Loss: 0.00727502, Conformal Loss: 0.00000615
# Epoch [300/600], Loss: 0.00602983, Reconstruction Loss: 0.00598851, Conformal Loss: 0.00000574
# Epoch [300/600], Validation Loss: 0.00670940, Reconstruction Loss: 0.00666783, Conformal Loss: 0.00000578
# Epoch [400/600], Loss: 0.00567363, Reconstruction Loss: 0.00563248, Conformal Loss: 0.00000572
# Epoch [400/600], Validation Loss: 0.00644549, Reconstruction Loss: 0.00640320, Conformal Loss: 0.00000587
# Epoch [500/600], Loss: 0.00548681, Reconstruction Loss: 0.00544676, Conformal Loss: 0.00000557
# Epoch [500/600], Validation Loss: 0.00625404, Reconstruction Loss: 0.00621379, Conformal Loss: 0.00000559
# Epoch [600/600], Loss: 0.00539215, Reconstruction Loss: 0.00535202, Conformal Loss: 0.00000558
# Epoch [600/600], Validation Loss: 0.00616906, Reconstruction Loss: 0.00612970, Conformal Loss: 0.00000547
# Model 2/3 with lambda_iso=7.197 trained and saved.
# Training model 3/3 with lambda_iso=7.197
# Epoch [100/600], Loss: 0.01268476, Reconstruction Loss: 0.01263286, Conformal Loss: 0.00000721
# Epoch [100/600], Validation Loss: 0.01277918, Reconstruction Loss: 0.01272712, Conformal Loss: 0.00000723
# Epoch [200/600], Loss: 0.00819463, Reconstruction Loss: 0.00813704, Conformal Loss: 0.00000800
# Epoch [200/600], Validation Loss: 0.00849347, Reconstruction Loss: 0.00843688, Conformal Loss: 0.00000786
# Epoch [300/600], Loss: 0.00687487, Reconstruction Loss: 0.00681533, Conformal Loss: 0.00000827
# Epoch [300/600], Validation Loss: 0.00729573, Reconstruction Loss: 0.00723548, Conformal Loss: 0.00000837
# Epoch [400/600], Loss: 0.00645194, Reconstruction Loss: 0.00639468, Conformal Loss: 0.00000796
# Epoch [400/600], Validation Loss: 0.00691568, Reconstruction Loss: 0.00685828, Conformal Loss: 0.00000798
# Epoch [500/600], Loss: 0.00625604, Reconstruction Loss: 0.00620079, Conformal Loss: 0.00000768
# Epoch [500/600], Validation Loss: 0.00675607, Reconstruction Loss: 0.00670034, Conformal Loss: 0.00000774
# Epoch [600/600], Loss: 0.00614085, Reconstruction Loss: 0.00608538, Conformal Loss: 0.00000771
# Epoch [600/600], Validation Loss: 0.00665847, Reconstruction Loss: 0.00660308, Conformal Loss: 0.00000770
# Model 3/3 with lambda_iso=7.197 trained and saved.
# Training model 1/3 with lambda_iso=19.307
# Epoch [100/600], Loss: 0.01489991, Reconstruction Loss: 0.01480421, Conformal Loss: 0.00000496
# Epoch [100/600], Validation Loss: 0.01488284, Reconstruction Loss: 0.01478455, Conformal Loss: 0.00000509
# Epoch [200/600], Loss: 0.00974755, Reconstruction Loss: 0.00966174, Conformal Loss: 0.00000444
# Epoch [200/600], Validation Loss: 0.01018759, Reconstruction Loss: 0.01010058, Conformal Loss: 0.00000451
# Epoch [300/600], Loss: 0.00757587, Reconstruction Loss: 0.00749031, Conformal Loss: 0.00000443
# Epoch [300/600], Validation Loss: 0.00798495, Reconstruction Loss: 0.00789914, Conformal Loss: 0.00000444
# Epoch [400/600], Loss: 0.00696363, Reconstruction Loss: 0.00688420, Conformal Loss: 0.00000411
# Epoch [400/600], Validation Loss: 0.00741663, Reconstruction Loss: 0.00733767, Conformal Loss: 0.00000409
# Epoch [500/600], Loss: 0.00672402, Reconstruction Loss: 0.00664819, Conformal Loss: 0.00000393
# Epoch [500/600], Validation Loss: 0.00717110, Reconstruction Loss: 0.00709483, Conformal Loss: 0.00000395
# Epoch [600/600], Loss: 0.00656931, Reconstruction Loss: 0.00649528, Conformal Loss: 0.00000383
# Epoch [600/600], Validation Loss: 0.00706294, Reconstruction Loss: 0.00698850, Conformal Loss: 0.00000386
# Model 1/3 with lambda_iso=19.307 trained and saved.
# Training model 2/3 with lambda_iso=19.307
# Epoch [100/600], Loss: 0.01330102, Reconstruction Loss: 0.01324843, Conformal Loss: 0.00000272
# Epoch [100/600], Validation Loss: 0.01352111, Reconstruction Loss: 0.01346848, Conformal Loss: 0.00000273
# Epoch [200/600], Loss: 0.00917853, Reconstruction Loss: 0.00911906, Conformal Loss: 0.00000308
# Epoch [200/600], Validation Loss: 0.00959312, Reconstruction Loss: 0.00953320, Conformal Loss: 0.00000310
# Epoch [300/600], Loss: 0.00786332, Reconstruction Loss: 0.00780437, Conformal Loss: 0.00000305
# Epoch [300/600], Validation Loss: 0.00837792, Reconstruction Loss: 0.00832030, Conformal Loss: 0.00000298
# Epoch [400/600], Loss: 0.00733741, Reconstruction Loss: 0.00727907, Conformal Loss: 0.00000302
# Epoch [400/600], Validation Loss: 0.00793380, Reconstruction Loss: 0.00787662, Conformal Loss: 0.00000296
# Epoch [500/600], Loss: 0.00709359, Reconstruction Loss: 0.00703551, Conformal Loss: 0.00000301
# Epoch [500/600], Validation Loss: 0.00775453, Reconstruction Loss: 0.00769814, Conformal Loss: 0.00000292
# Epoch [600/600], Loss: 0.00699056, Reconstruction Loss: 0.00693354, Conformal Loss: 0.00000295
# Epoch [600/600], Validation Loss: 0.00765927, Reconstruction Loss: 0.00760366, Conformal Loss: 0.00000288
# Model 2/3 with lambda_iso=19.307 trained and saved.
# Training model 3/3 with lambda_iso=19.307
# Epoch [100/600], Loss: 0.01130215, Reconstruction Loss: 0.01121615, Conformal Loss: 0.00000445
# Epoch [100/600], Validation Loss: 0.01166965, Reconstruction Loss: 0.01158647, Conformal Loss: 0.00000431
# Epoch [200/600], Loss: 0.00755291, Reconstruction Loss: 0.00746876, Conformal Loss: 0.00000436
# Epoch [200/600], Validation Loss: 0.00815727, Reconstruction Loss: 0.00807253, Conformal Loss: 0.00000439
# Epoch [300/600], Loss: 0.00652423, Reconstruction Loss: 0.00644403, Conformal Loss: 0.00000415
# Epoch [300/600], Validation Loss: 0.00720071, Reconstruction Loss: 0.00711970, Conformal Loss: 0.00000420
# Epoch [400/600], Loss: 0.00613765, Reconstruction Loss: 0.00606153, Conformal Loss: 0.00000394
# Epoch [400/600], Validation Loss: 0.00686462, Reconstruction Loss: 0.00678844, Conformal Loss: 0.00000395
# Epoch [500/600], Loss: 0.00593724, Reconstruction Loss: 0.00586419, Conformal Loss: 0.00000378
# Epoch [500/600], Validation Loss: 0.00667779, Reconstruction Loss: 0.00660520, Conformal Loss: 0.00000376
# Epoch [600/600], Loss: 0.00584683, Reconstruction Loss: 0.00577601, Conformal Loss: 0.00000367
# Epoch [600/600], Validation Loss: 0.00659187, Reconstruction Loss: 0.00651937, Conformal Loss: 0.00000376
# Model 3/3 with lambda_iso=19.307 trained and saved.
# Training model 1/3 with lambda_iso=51.795
# Epoch [100/600], Loss: 0.01116499, Reconstruction Loss: 0.01101462, Conformal Loss: 0.00000290
# Epoch [100/600], Validation Loss: 0.01140371, Reconstruction Loss: 0.01124537, Conformal Loss: 0.00000306
# Epoch [200/600], Loss: 0.00748743, Reconstruction Loss: 0.00736095, Conformal Loss: 0.00000244
# Epoch [200/600], Validation Loss: 0.00795913, Reconstruction Loss: 0.00782859, Conformal Loss: 0.00000252
# Epoch [300/600], Loss: 0.00651233, Reconstruction Loss: 0.00640540, Conformal Loss: 0.00000206
# Epoch [300/600], Validation Loss: 0.00708079, Reconstruction Loss: 0.00697307, Conformal Loss: 0.00000208
# Epoch [400/600], Loss: 0.00612407, Reconstruction Loss: 0.00602767, Conformal Loss: 0.00000186
# Epoch [400/600], Validation Loss: 0.00677342, Reconstruction Loss: 0.00667530, Conformal Loss: 0.00000189
# Epoch [500/600], Loss: 0.00594368, Reconstruction Loss: 0.00585238, Conformal Loss: 0.00000176
# Epoch [500/600], Validation Loss: 0.00661130, Reconstruction Loss: 0.00651820, Conformal Loss: 0.00000180
# Epoch [600/600], Loss: 0.00584445, Reconstruction Loss: 0.00575727, Conformal Loss: 0.00000168
# Epoch [600/600], Validation Loss: 0.00653049, Reconstruction Loss: 0.00644078, Conformal Loss: 0.00000173
# Model 1/3 with lambda_iso=51.795 trained and saved.
# Training model 2/3 with lambda_iso=51.795
# Epoch [100/600], Loss: 0.00947048, Reconstruction Loss: 0.00932900, Conformal Loss: 0.00000273
# Epoch [100/600], Validation Loss: 0.00976483, Reconstruction Loss: 0.00962452, Conformal Loss: 0.00000271
# Epoch [200/600], Loss: 0.00659578, Reconstruction Loss: 0.00648139, Conformal Loss: 0.00000221
# Epoch [200/600], Validation Loss: 0.00709447, Reconstruction Loss: 0.00697855, Conformal Loss: 0.00000224
# Epoch [300/600], Loss: 0.00593301, Reconstruction Loss: 0.00583507, Conformal Loss: 0.00000189
# Epoch [300/600], Validation Loss: 0.00655200, Reconstruction Loss: 0.00645380, Conformal Loss: 0.00000190
# Epoch [400/600], Loss: 0.00562810, Reconstruction Loss: 0.00553849, Conformal Loss: 0.00000173
# Epoch [400/600], Validation Loss: 0.00634455, Reconstruction Loss: 0.00625473, Conformal Loss: 0.00000173
# Epoch [500/600], Loss: 0.00549043, Reconstruction Loss: 0.00540557, Conformal Loss: 0.00000164
# Epoch [500/600], Validation Loss: 0.00622868, Reconstruction Loss: 0.00614329, Conformal Loss: 0.00000165
# Epoch [600/600], Loss: 0.00540585, Reconstruction Loss: 0.00532415, Conformal Loss: 0.00000158
# Epoch [600/600], Validation Loss: 0.00616637, Reconstruction Loss: 0.00608392, Conformal Loss: 0.00000159
# Model 2/3 with lambda_iso=51.795 trained and saved.
# Training model 3/3 with lambda_iso=51.795
# Epoch [100/600], Loss: 0.01377967, Reconstruction Loss: 0.01365030, Conformal Loss: 0.00000250
# Epoch [100/600], Validation Loss: 0.01387763, Reconstruction Loss: 0.01374672, Conformal Loss: 0.00000253
# Epoch [200/600], Loss: 0.01008848, Reconstruction Loss: 0.00998153, Conformal Loss: 0.00000206
# Epoch [200/600], Validation Loss: 0.01051588, Reconstruction Loss: 0.01041187, Conformal Loss: 0.00000201
# Epoch [300/600], Loss: 0.00825398, Reconstruction Loss: 0.00814858, Conformal Loss: 0.00000204
# Epoch [300/600], Validation Loss: 0.00869234, Reconstruction Loss: 0.00858823, Conformal Loss: 0.00000201
# Epoch [400/600], Loss: 0.00745249, Reconstruction Loss: 0.00735295, Conformal Loss: 0.00000192
# Epoch [400/600], Validation Loss: 0.00789453, Reconstruction Loss: 0.00779427, Conformal Loss: 0.00000194
# Epoch [500/600], Loss: 0.00715092, Reconstruction Loss: 0.00705488, Conformal Loss: 0.00000185
# Epoch [500/600], Validation Loss: 0.00761720, Reconstruction Loss: 0.00752088, Conformal Loss: 0.00000186
# Epoch [600/600], Loss: 0.00700724, Reconstruction Loss: 0.00691465, Conformal Loss: 0.00000179
# Epoch [600/600], Validation Loss: 0.00749007, Reconstruction Loss: 0.00739575, Conformal Loss: 0.00000182
# Model 3/3 with lambda_iso=51.795 trained and saved.
# Training model 1/3 with lambda_iso=138.950
# Epoch [100/600], Loss: 0.10548902, Reconstruction Loss: 0.10548902, Conformal Loss: 0.00000000
# Epoch [100/600], Validation Loss: 0.10602356, Reconstruction Loss: 0.10602356, Conformal Loss: 0.00000000
# Epoch [200/600], Loss: 0.09484115, Reconstruction Loss: 0.09484116, Conformal Loss: 0.00000000
# Epoch [200/600], Validation Loss: 0.09559786, Reconstruction Loss: 0.09559786, Conformal Loss: 0.00000000
# Epoch [300/600], Loss: 0.09214025, Reconstruction Loss: 0.09214024, Conformal Loss: 0.00000000
# Epoch [300/600], Validation Loss: 0.09301171, Reconstruction Loss: 0.09301171, Conformal Loss: 0.00000000
# Epoch [400/600], Loss: 0.09121075, Reconstruction Loss: 0.09121075, Conformal Loss: 0.00000000
# Epoch [400/600], Validation Loss: 0.09207308, Reconstruction Loss: 0.09207308, Conformal Loss: 0.00000000
# Epoch [500/600], Loss: 0.09080153, Reconstruction Loss: 0.09080151, Conformal Loss: 0.00000000
# Epoch [500/600], Validation Loss: 0.09165842, Reconstruction Loss: 0.09165842, Conformal Loss: 0.00000000
# Epoch [600/600], Loss: 0.09056446, Reconstruction Loss: 0.09056446, Conformal Loss: 0.00000000
# Epoch [600/600], Validation Loss: 0.09145605, Reconstruction Loss: 0.09145605, Conformal Loss: 0.00000000
# Model 1/3 with lambda_iso=138.950 trained and saved.
# Training model 2/3 with lambda_iso=138.950
# Epoch [100/600], Loss: 0.00974407, Reconstruction Loss: 0.00951373, Conformal Loss: 0.00000166
# Epoch [100/600], Validation Loss: 0.01008365, Reconstruction Loss: 0.00985476, Conformal Loss: 0.00000165
# Epoch [200/600], Loss: 0.00662908, Reconstruction Loss: 0.00646455, Conformal Loss: 0.00000118
# Epoch [200/600], Validation Loss: 0.00724618, Reconstruction Loss: 0.00708374, Conformal Loss: 0.00000117
# Epoch [300/600], Loss: 0.00589124, Reconstruction Loss: 0.00575873, Conformal Loss: 0.00000095
# Epoch [300/600], Validation Loss: 0.00659651, Reconstruction Loss: 0.00646392, Conformal Loss: 0.00000095
# Epoch [400/600], Loss: 0.00557295, Reconstruction Loss: 0.00545630, Conformal Loss: 0.00000084
# Epoch [400/600], Validation Loss: 0.00633720, Reconstruction Loss: 0.00621864, Conformal Loss: 0.00000085
# Epoch [500/600], Loss: 0.00541657, Reconstruction Loss: 0.00530788, Conformal Loss: 0.00000078
# Epoch [500/600], Validation Loss: 0.00620259, Reconstruction Loss: 0.00609324, Conformal Loss: 0.00000079
# Epoch [600/600], Loss: 0.00533365, Reconstruction Loss: 0.00522826, Conformal Loss: 0.00000076
# Epoch [600/600], Validation Loss: 0.00613007, Reconstruction Loss: 0.00602556, Conformal Loss: 0.00000075
# Model 2/3 with lambda_iso=138.950 trained and saved.
# Training model 3/3 with lambda_iso=138.950
# Epoch [100/600], Loss: 0.01154486, Reconstruction Loss: 0.01134509, Conformal Loss: 0.00000144
# Epoch [100/600], Validation Loss: 0.01196435, Reconstruction Loss: 0.01177048, Conformal Loss: 0.00000140
# Epoch [200/600], Loss: 0.00791898, Reconstruction Loss: 0.00776798, Conformal Loss: 0.00000109
# Epoch [200/600], Validation Loss: 0.00840547, Reconstruction Loss: 0.00825190, Conformal Loss: 0.00000111
# Epoch [300/600], Loss: 0.00692515, Reconstruction Loss: 0.00680044, Conformal Loss: 0.00000090
# Epoch [300/600], Validation Loss: 0.00751644, Reconstruction Loss: 0.00739289, Conformal Loss: 0.00000089
# Epoch [400/600], Loss: 0.00649185, Reconstruction Loss: 0.00638039, Conformal Loss: 0.00000080
# Epoch [400/600], Validation Loss: 0.00716147, Reconstruction Loss: 0.00705074, Conformal Loss: 0.00000080
# Epoch [500/600], Loss: 0.00628130, Reconstruction Loss: 0.00617709, Conformal Loss: 0.00000075
# Epoch [500/600], Validation Loss: 0.00695465, Reconstruction Loss: 0.00684987, Conformal Loss: 0.00000075
# Epoch [600/600], Loss: 0.00616850, Reconstruction Loss: 0.00606781, Conformal Loss: 0.00000072
# Epoch [600/600], Validation Loss: 0.00686139, Reconstruction Loss: 0.00675892, Conformal Loss: 0.00000074
# Model 3/3 with lambda_iso=138.950 trained and saved.
# Training model 1/3 with lambda_iso=372.759
# Epoch [100/600], Loss: 0.01326263, Reconstruction Loss: 0.01301967, Conformal Loss: 0.00000065
# Epoch [100/600], Validation Loss: 0.01357876, Reconstruction Loss: 0.01332689, Conformal Loss: 0.00000068
# Epoch [200/600], Loss: 0.00869321, Reconstruction Loss: 0.00850385, Conformal Loss: 0.00000051
# Epoch [200/600], Validation Loss: 0.00931687, Reconstruction Loss: 0.00912765, Conformal Loss: 0.00000051
# Epoch [300/600], Loss: 0.00715999, Reconstruction Loss: 0.00700193, Conformal Loss: 0.00000042
# Epoch [300/600], Validation Loss: 0.00787481, Reconstruction Loss: 0.00771073, Conformal Loss: 0.00000044
# Epoch [400/600], Loss: 0.00661852, Reconstruction Loss: 0.00647831, Conformal Loss: 0.00000038
# Epoch [400/600], Validation Loss: 0.00738033, Reconstruction Loss: 0.00724177, Conformal Loss: 0.00000037
# Epoch [500/600], Loss: 0.00637554, Reconstruction Loss: 0.00624647, Conformal Loss: 0.00000035
# Epoch [500/600], Validation Loss: 0.00717434, Reconstruction Loss: 0.00704798, Conformal Loss: 0.00000034
# Epoch [600/600], Loss: 0.00625526, Reconstruction Loss: 0.00613521, Conformal Loss: 0.00000032
# Epoch [600/600], Validation Loss: 0.00707342, Reconstruction Loss: 0.00694924, Conformal Loss: 0.00000033
# Model 1/3 with lambda_iso=372.759 trained and saved.
# Training model 2/3 with lambda_iso=372.759
# Epoch [100/600], Loss: 0.01071902, Reconstruction Loss: 0.01049483, Conformal Loss: 0.00000060
# Epoch [100/600], Validation Loss: 0.01107362, Reconstruction Loss: 0.01084628, Conformal Loss: 0.00000061
# Epoch [200/600], Loss: 0.00714985, Reconstruction Loss: 0.00699038, Conformal Loss: 0.00000043
# Epoch [200/600], Validation Loss: 0.00774862, Reconstruction Loss: 0.00758895, Conformal Loss: 0.00000043
# Epoch [300/600], Loss: 0.00630093, Reconstruction Loss: 0.00617189, Conformal Loss: 0.00000035
# Epoch [300/600], Validation Loss: 0.00703656, Reconstruction Loss: 0.00690882, Conformal Loss: 0.00000034
# Epoch [400/600], Loss: 0.00595479, Reconstruction Loss: 0.00583925, Conformal Loss: 0.00000031
# Epoch [400/600], Validation Loss: 0.00674520, Reconstruction Loss: 0.00663058, Conformal Loss: 0.00000031
# Epoch [500/600], Loss: 0.00575486, Reconstruction Loss: 0.00564653, Conformal Loss: 0.00000029
# Epoch [500/600], Validation Loss: 0.00658588, Reconstruction Loss: 0.00647735, Conformal Loss: 0.00000029
# Epoch [600/600], Loss: 0.00565858, Reconstruction Loss: 0.00555350, Conformal Loss: 0.00000028
# Epoch [600/600], Validation Loss: 0.00650307, Reconstruction Loss: 0.00639858, Conformal Loss: 0.00000028
# Model 2/3 with lambda_iso=372.759 trained and saved.
# Training model 3/3 with lambda_iso=372.759
# Epoch [100/600], Loss: 0.01079150, Reconstruction Loss: 0.01048655, Conformal Loss: 0.00000082
# Epoch [100/600], Validation Loss: 0.01125336, Reconstruction Loss: 0.01095326, Conformal Loss: 0.00000081
# Epoch [200/600], Loss: 0.00765506, Reconstruction Loss: 0.00746330, Conformal Loss: 0.00000051
# Epoch [200/600], Validation Loss: 0.00826485, Reconstruction Loss: 0.00806819, Conformal Loss: 0.00000053
# Epoch [300/600], Loss: 0.00676215, Reconstruction Loss: 0.00660870, Conformal Loss: 0.00000041
# Epoch [300/600], Validation Loss: 0.00740290, Reconstruction Loss: 0.00724691, Conformal Loss: 0.00000042
# Epoch [400/600], Loss: 0.00635411, Reconstruction Loss: 0.00621927, Conformal Loss: 0.00000036
# Epoch [400/600], Validation Loss: 0.00704155, Reconstruction Loss: 0.00690690, Conformal Loss: 0.00000036
# Epoch [500/600], Loss: 0.00615347, Reconstruction Loss: 0.00602881, Conformal Loss: 0.00000033
# Epoch [500/600], Validation Loss: 0.00688672, Reconstruction Loss: 0.00676227, Conformal Loss: 0.00000033
# Epoch [600/600], Loss: 0.00606708, Reconstruction Loss: 0.00594612, Conformal Loss: 0.00000032
# Epoch [600/600], Validation Loss: 0.00681284, Reconstruction Loss: 0.00669313, Conformal Loss: 0.00000032
# Model 3/3 with lambda_iso=372.759 trained and saved.
# Training model 1/3 with lambda_iso=1000.000
# Epoch [100/600], Loss: 0.01156004, Reconstruction Loss: 0.01128392, Conformal Loss: 0.00000028
# Epoch [100/600], Validation Loss: 0.01195456, Reconstruction Loss: 0.01168425, Conformal Loss: 0.00000027
# Epoch [200/600], Loss: 0.00696542, Reconstruction Loss: 0.00676347, Conformal Loss: 0.00000020
# Epoch [200/600], Validation Loss: 0.00750888, Reconstruction Loss: 0.00730624, Conformal Loss: 0.00000020
# Epoch [300/600], Loss: 0.00599506, Reconstruction Loss: 0.00584092, Conformal Loss: 0.00000015
# Epoch [300/600], Validation Loss: 0.00666301, Reconstruction Loss: 0.00651049, Conformal Loss: 0.00000015
# Epoch [400/600], Loss: 0.00560009, Reconstruction Loss: 0.00546592, Conformal Loss: 0.00000013
# Epoch [400/600], Validation Loss: 0.00635801, Reconstruction Loss: 0.00622590, Conformal Loss: 0.00000013
# Epoch [500/600], Loss: 0.00541721, Reconstruction Loss: 0.00529476, Conformal Loss: 0.00000012
# Epoch [500/600], Validation Loss: 0.00622558, Reconstruction Loss: 0.00610304, Conformal Loss: 0.00000012
# Epoch [600/600], Loss: 0.00531845, Reconstruction Loss: 0.00520108, Conformal Loss: 0.00000012
# Epoch [600/600], Validation Loss: 0.00615138, Reconstruction Loss: 0.00603486, Conformal Loss: 0.00000012
# Model 1/3 with lambda_iso=1000.000 trained and saved.
# Training model 2/3 with lambda_iso=1000.000
# Epoch [100/600], Loss: 0.01166524, Reconstruction Loss: 0.01140704, Conformal Loss: 0.00000026
# Epoch [100/600], Validation Loss: 0.01206229, Reconstruction Loss: 0.01180661, Conformal Loss: 0.00000026
# Epoch [200/600], Loss: 0.00795830, Reconstruction Loss: 0.00778044, Conformal Loss: 0.00000018
# Epoch [200/600], Validation Loss: 0.00865000, Reconstruction Loss: 0.00847135, Conformal Loss: 0.00000018
# Epoch [300/600], Loss: 0.00691410, Reconstruction Loss: 0.00676808, Conformal Loss: 0.00000015
# Epoch [300/600], Validation Loss: 0.00771980, Reconstruction Loss: 0.00757434, Conformal Loss: 0.00000015
# Epoch [400/600], Loss: 0.00649510, Reconstruction Loss: 0.00636326, Conformal Loss: 0.00000013
# Epoch [400/600], Validation Loss: 0.00732879, Reconstruction Loss: 0.00719907, Conformal Loss: 0.00000013
# Epoch [500/600], Loss: 0.00626082, Reconstruction Loss: 0.00613802, Conformal Loss: 0.00000012
# Epoch [500/600], Validation Loss: 0.00711979, Reconstruction Loss: 0.00699646, Conformal Loss: 0.00000012
# Epoch [600/600], Loss: 0.00615454, Reconstruction Loss: 0.00603680, Conformal Loss: 0.00000012
# Epoch [600/600], Validation Loss: 0.00702454, Reconstruction Loss: 0.00690639, Conformal Loss: 0.00000012
# Model 2/3 with lambda_iso=1000.000 trained and saved.
# Training model 3/3 with lambda_iso=1000.000
# Epoch [100/600], Loss: 0.01222680, Reconstruction Loss: 0.01191085, Conformal Loss: 0.00000032
# Epoch [100/600], Validation Loss: 0.01255475, Reconstruction Loss: 0.01224077, Conformal Loss: 0.00000031
# Epoch [200/600], Loss: 0.00729813, Reconstruction Loss: 0.00707339, Conformal Loss: 0.00000022
# Epoch [200/600], Validation Loss: 0.00787881, Reconstruction Loss: 0.00765507, Conformal Loss: 0.00000022
# Epoch [300/600], Loss: 0.00641393, Reconstruction Loss: 0.00624996, Conformal Loss: 0.00000016
# Epoch [300/600], Validation Loss: 0.00717031, Reconstruction Loss: 0.00700335, Conformal Loss: 0.00000017
# Epoch [400/600], Loss: 0.00605579, Reconstruction Loss: 0.00591684, Conformal Loss: 0.00000014
# Epoch [400/600], Validation Loss: 0.00686485, Reconstruction Loss: 0.00672213, Conformal Loss: 0.00000014
# Epoch [500/600], Loss: 0.00587481, Reconstruction Loss: 0.00574669, Conformal Loss: 0.00000013
# Epoch [500/600], Validation Loss: 0.00672821, Reconstruction Loss: 0.00659555, Conformal Loss: 0.00000013
# Epoch [600/600], Loss: 0.00578584, Reconstruction Loss: 0.00566448, Conformal Loss: 0.00000012
# Epoch [600/600], Validation Loss: 0.00665513, Reconstruction Loss: 0.00653331, Conformal Loss: 0.00000012
# Model 3/3 with lambda_iso=1000.000 trained and saved.

# %%
plt.plot(lambda_isos, recon_errors, label='Reconstruction Error')
plt.plot(lambda_isos, regularization_errors, label='Regularization Error')
plt.ylim(0.005, 0.01)
plt.xscale('log')
plt.xlabel('Lambda (log scale)')
plt.ylabel('Error')
plt.title('Reconstruction and Regularization Errors vs Lambda')
plt.legend()
plt.show()

# %%
plt.plot(lambda_isos, recon_errors, label='Reconstruction Error')
plt.plot(lambda_isos, regularization_errors, label='Regularization Error')
plt.ylim(0.0, 0.00002)
plt.xscale('log')
plt.xlabel('Lambda (log scale)')
plt.ylabel('Error')
plt.title('Reconstruction and Regularization Errors vs Lambda')
plt.legend()
plt.show()

# %%
# plot samples and latent space at different lambdas
fig, axs = plt.subplots(2, len(lambda_isos), figsize=(40, 8))
for i, lambda_iso in enumerate(lambda_isos):
    model_path = f"models/conformal_autoencoder_mnist_vec/lambda_{lambda_iso:.3f}_model_2.pth"
    model = ConformalAutoencoder(encoder, decoder, lambda_conf=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))

    # model.eval()
    # with torch.no_grad():
    encoded_data = model.encode(val_data[:10])
    reconstruction = model.decode(encoded_data)

    axs[0, i].imshow(reconstruction[2].view(32, 32).cpu().detach().numpy(), cmap='gray')
    axs[0, i].set_title(f'Lambda: {lambda_iso:.3f}')
    axs[0, i].axis('off')

    axs[1, i].imshow(val_data[2].view(32, 32).cpu().detach().numpy(), cmap='gray')
    axs[1, i].set_title(f'Lambda: {lambda_iso:.3f}')
    axs[1, i].axis('off')
plt.tight_layout()

# %%
fig, axs = plt.subplots(len(lambda_isos), 1, figsize=(8, 40))
for j, lambda_iso in enumerate(lambda_isos):
    model_path = f"models/conformal_autoencoder_mnist_vec/lambda_{lambda_iso:.3f}_model_1.pth"
    model = ConformalAutoencoder(encoder, decoder, lambda_conf=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))

    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data[:200])
        reconstruction = model.decode(encoded_data)

    JtJs = torch.zeros((latent_dim, latent_dim)).to(device)
    for i, z in enumerate(encoded_data):
        z = z.unsqueeze(0)  # Add batch dimension

        J = torch.autograd.functional.jacobian(model.decoder, z)[0,0,:,:,0,:]
        J = J.reshape(-1, 32)  # Reshape to (latent_dim, flattened_output_dim)
        JtJ = J.transpose(0, 1) @ J
        JtJs += JtJ

    JtJs /= encoded_data.shape[0]  # Average over all points

    p = axs[j].imshow(JtJs.cpu().detach().numpy(), cmap='hot')
    axs[j].set_title(f'Lambda: {lambda_iso:.3f}')
    axs[j].axis('off')
    plt.colorbar(p)
plt.tight_layout()

# %%
conformal_autoencoder.eval()
with torch.no_grad():
    encoded_data = conformal_autoencoder.encode(val_data[:1000])
    reconstruction = conformal_autoencoder.decode(encoded_data)

JtJs = torch.zeros((latent_dim, latent_dim)).to(device)
for i, z in enumerate(encoded_data):
    z = z.unsqueeze(0)  # Add batch dimension

    J = torch.autograd.functional.jacobian(conformal_autoencoder.decoder, z)[0,0,:,:,0,:]
    J = J.reshape(-1, 32)  # Reshape to (latent_dim, flattened_output_dim)
    JtJ = J.transpose(0, 1) @ J
    JtJs += JtJ

JtJs /= encoded_data.shape[0]  # Average over all points

plt.imshow(JtJs.cpu().numpy(), cmap='hot')
plt.colorbar()
plt.title('Average J^T J')
plt.axis('off')
plt.show()

# %%
model_path = f"models/conformal_autoencoder_mnist_vec/lambda_{lambda_isos[-1]:.3f}_model_1.pth"
model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_isos[-1]).to(device)
model.load_state_dict(torch.load(model_path))

model.eval()
with torch.no_grad():
    encoded_data = model.encode(val_data[:2])
    reconstruction = model.decode(encoded_data)


    for i, z in enumerate(encoded_data):
        z = z.unsqueeze(0)  # Add batch dimension
        y = model.decoder(z)  # Decode to get reconstruction
        y = y.squeeze(0)  # Remove batch dimension

        # Compute the Jacobian J of the decoder at point z
        J = torch.autograd.functional.jacobian(model.decoder, z)[0,:,0,:]
        JtJ = J.transpose(0, 1) @ J
        print(JtJ.size())
        print(encoded_data.size())

    #     eye = torch.eye(JtJ.size(0), device=device)
    #     off_diag_mask = 1.0 - eye
    #     off_diag_elements = JtJ[off_diag_mask.bool()]
    #     loss_matrix = off_diag_elements ** 2

    #     losses.append(loss_matrix.mean().item())
    
    # return np.mean(losses).item()
# Out:
# torch.Size([28, 28, 1, 64, 1, 1])
# torch.Size([2, 64, 1, 1])
# torch.Size([28, 28, 1, 64, 1, 1])
# torch.Size([2, 64, 1, 1])

# %%
print(JtJ[:,:,0,0,0,0])
# Out:
# tensor([[ 3.0352e-18,  5.2367e-17,  2.9216e-18,  1.0972e-19,  5.9667e-21,
#           9.4161e-21,  1.8404e-21,  2.0862e-22,  4.2756e-22,  2.7949e-20,
#           9.5245e-20,  7.9838e-20,  2.1337e-22,  1.2245e-24,  4.7852e-26,
#           3.2307e-27, -4.6334e-24, -4.1562e-23, -4.6581e-21, -5.7762e-21,
#           9.4572e-24,  4.5367e-25,  2.4468e-23,  3.7554e-24,  8.7466e-24,
#           2.5008e-23,  3.5209e-21,  2.7895e-17],
#         [ 5.2367e-17,  9.0350e-16,  5.0408e-17,  1.8931e-18,  1.0295e-19,
#           1.6246e-19,  3.1753e-20,  3.5994e-21,  7.3769e-21,  4.8221e-19,
#           1.6433e-18,  1.3775e-18,  3.6813e-21,  2.1127e-23,  8.2561e-25,
#           5.5740e-26, -7.9941e-23, -7.1709e-22, -8.0368e-20, -9.9658e-20,
#           1.6317e-22,  7.8273e-24,  4.2215e-22,  6.4794e-23,  1.5091e-22,
#           4.3147e-22,  6.0748e-20,  4.8128e-16],
#         [ 2.9216e-18,  5.0408e-17,  2.8124e-18,  1.0562e-19,  5.7435e-21,
#           9.0639e-21,  1.7716e-21,  2.0082e-22,  4.1157e-22,  2.6903e-20,
#           9.1682e-20,  7.6852e-20,  2.0539e-22,  1.1787e-24,  4.6063e-26,
#           3.1098e-27, -4.4601e-24, -4.0008e-23, -4.4839e-21, -5.5601e-21,
#           9.1035e-24,  4.3670e-25,  2.3553e-23,  3.6150e-24,  8.4194e-24,
#           2.4072e-23,  3.3892e-21,  2.6852e-17],
#         [ 1.0972e-19,  1.8931e-18,  1.0562e-19,  3.9664e-21,  2.1570e-22,
#           3.4039e-22,  6.6531e-23,  7.5417e-24,  1.5456e-23,  1.0104e-21,
#           3.4431e-21,  2.8862e-21,  7.7133e-24,  4.4265e-26,  1.7299e-27,
#           1.1679e-28, -1.6750e-25, -1.5025e-24, -1.6839e-22, -2.0881e-22,
#           3.4188e-25,  1.6400e-26,  8.8452e-25,  1.3576e-25,  3.1619e-25,
#           9.0403e-25,  1.2728e-22,  1.0084e-18],
#         [ 5.9667e-21,  1.0295e-19,  5.7435e-21,  2.1570e-22,  1.1730e-23,
#           1.8511e-23,  3.6180e-24,  4.1012e-25,  8.4053e-25,  5.4943e-23,
#           1.8724e-22,  1.5695e-22,  4.1945e-25,  2.4072e-27,  9.4071e-29,
#           6.3510e-30, -9.1085e-27, -8.1705e-26, -9.1572e-24, -1.1355e-23,
#           1.8592e-26,  8.9184e-28,  4.8100e-26,  7.3826e-27,  1.7195e-26,
#           4.9162e-26,  6.9216e-24,  5.4838e-20],
#         [ 9.4161e-21,  1.6246e-19,  9.0639e-21,  3.4039e-22,  1.8511e-23,
#           2.9212e-23,  5.7096e-24,  6.4722e-25,  1.3264e-24,  8.6707e-23,
#           2.9548e-22,  2.4769e-22,  6.6194e-25,  3.7988e-27,  1.4845e-28,
#           1.0023e-29, -1.4374e-26, -1.2894e-25, -1.4451e-23, -1.7920e-23,
#           2.9339e-26,  1.4074e-27,  7.5908e-26,  1.1651e-26,  2.7135e-26,
#           7.7583e-26,  1.0923e-23,  8.6540e-20],
#         [ 1.8404e-21,  3.1753e-20,  1.7716e-21,  6.6531e-23,  3.6180e-24,
#           5.7096e-24,  1.1160e-24,  1.2650e-25,  2.5926e-25,  1.6947e-23,
#           5.7753e-23,  4.8411e-23,  1.2938e-25,  7.4248e-28,  2.9016e-29,
#           1.9589e-30, -2.8095e-27, -2.5202e-26, -2.8245e-24, -3.5024e-24,
#           5.7345e-27,  2.7509e-28,  1.4836e-26,  2.2771e-27,  5.3036e-27,
#           1.5164e-26,  2.1350e-24,  1.6915e-20],
#         [ 2.0862e-22,  3.5994e-21,  2.0082e-22,  7.5417e-24,  4.1012e-25,
#           6.4722e-25,  1.2650e-25,  1.4340e-26,  2.9389e-26,  1.9211e-24,
#           6.5467e-24,  5.4877e-24,  1.4666e-26,  8.4166e-29,  3.2892e-30,
#           2.2206e-31, -3.1848e-28, -2.8568e-27, -3.2018e-25, -3.9703e-25,
#           6.5005e-28,  3.1183e-29,  1.6818e-27,  2.5813e-28,  6.0120e-28,
#           1.7189e-27,  2.4201e-25,  1.9174e-21],
#         [ 4.2756e-22,  7.3769e-21,  4.1157e-22,  1.5456e-23,  8.4053e-25,
#           1.3264e-24,  2.5926e-25,  2.9389e-26,  6.0231e-26,  3.9372e-24,
#           1.3417e-23,  1.1247e-23,  3.0057e-26,  1.7249e-28,  6.7410e-30,
#           4.5510e-31, -6.5270e-28, -5.8549e-27, -6.5619e-25, -8.1369e-25,
#           1.3322e-27,  6.3908e-29,  3.4468e-27,  5.2903e-28,  1.2321e-27,
#           3.5228e-27,  4.9599e-25,  3.9296e-21],
#         [ 2.7949e-20,  4.8221e-19,  2.6903e-20,  1.0104e-21,  5.4943e-23,
#           8.6707e-23,  1.6947e-23,  1.9211e-24,  3.9372e-24,  2.5736e-22,
#           8.7705e-22,  7.3518e-22,  1.9648e-24,  1.1276e-26,  4.4064e-28,
#           2.9749e-29, -4.2666e-26, -3.8272e-25, -4.2894e-23, -5.3189e-23,
#           8.7086e-26,  4.1775e-27,  2.2531e-25,  3.4581e-26,  8.0542e-26,
#           2.3028e-25,  3.2422e-23,  2.5687e-19],
#         [ 9.5245e-20,  1.6433e-18,  9.1682e-20,  3.4431e-21,  1.8724e-22,
#           2.9548e-22,  5.7753e-23,  6.5467e-24,  1.3417e-23,  8.7705e-22,
#           2.9888e-21,  2.5054e-21,  6.6956e-24,  3.8425e-26,  1.5016e-27,
#           1.0138e-28, -1.4540e-25, -1.3042e-24, -1.4617e-22, -1.8126e-22,
#           2.9677e-25,  1.4236e-26,  7.6781e-25,  1.1785e-25,  2.7447e-25,
#           7.8475e-25,  1.1049e-22,  8.7536e-19],
#         [ 7.9838e-20,  1.3775e-18,  7.6852e-20,  2.8862e-21,  1.5695e-22,
#           2.4769e-22,  4.8411e-23,  5.4877e-24,  1.1247e-23,  7.3518e-22,
#           2.5054e-21,  2.1001e-21,  5.6126e-24,  3.2210e-26,  1.2587e-27,
#           8.4980e-29, -1.2188e-25, -1.0933e-24, -1.2253e-22, -1.5194e-22,
#           2.4877e-25,  1.1933e-26,  6.4362e-25,  9.8784e-26,  2.3007e-25,
#           6.5782e-25,  9.2616e-23,  7.3377e-19],
#         [ 2.1337e-22,  3.6813e-21,  2.0539e-22,  7.7133e-24,  4.1945e-25,
#           6.6194e-25,  1.2938e-25,  1.4666e-26,  3.0057e-26,  1.9648e-24,
#           6.6956e-24,  5.6126e-24,  1.5000e-26,  8.6080e-29,  3.3640e-30,
#           2.2711e-31, -3.2572e-28, -2.9218e-27, -3.2746e-25, -4.0606e-25,
#           6.6483e-28,  3.1892e-29,  1.7201e-27,  2.6400e-28,  6.1488e-28,
#           1.7580e-27,  2.4752e-25,  1.9610e-21],
#         [ 1.2245e-24,  2.1127e-23,  1.1787e-24,  4.4265e-26,  2.4072e-27,
#           3.7988e-27,  7.4248e-28,  8.4166e-29,  1.7249e-28,  1.1276e-26,
#           3.8425e-26,  3.2210e-26,  8.6080e-29,  4.9400e-31,  1.9305e-32,
#           1.3034e-33, -1.8693e-30, -1.6768e-29, -1.8792e-27, -2.3303e-27,
#           3.8154e-30,  1.8302e-31,  9.8712e-30,  1.5151e-30,  3.5287e-30,
#           1.0089e-29,  1.4205e-27,  1.1254e-23],
#         [ 4.7852e-26,  8.2561e-25,  4.6063e-26,  1.7299e-27,  9.4071e-29,
#           1.4845e-28,  2.9016e-29,  3.2892e-30,  6.7410e-30,  4.4064e-28,
#           1.5016e-27,  1.2587e-27,  3.3640e-30,  1.9305e-32,  7.5444e-34,
#           5.0934e-35, -7.3050e-32, -6.5527e-31, -7.3440e-29, -9.1067e-29,
#           1.4910e-31,  7.1525e-33,  3.8576e-31,  5.9208e-32,  1.3790e-31,
#           3.9427e-31,  5.5511e-29,  4.3979e-25],
#         [ 3.2307e-27,  5.5740e-26,  3.1098e-27,  1.1679e-28,  6.3510e-30,
#           1.0023e-29,  1.9589e-30,  2.2206e-31,  4.5510e-31,  2.9749e-29,
#           1.0138e-28,  8.4980e-29,  2.2711e-31,  1.3034e-33,  5.0934e-35,
#           3.4387e-36, -4.9318e-33, -4.4239e-32, -4.9581e-30, -6.1482e-30,
#           1.0066e-32,  4.8289e-34,  2.6044e-32,  3.9973e-33,  9.3099e-33,
#           2.6618e-32,  3.7477e-30,  2.9692e-26],
#         [-4.6334e-24, -7.9941e-23, -4.4601e-24, -1.6750e-25, -9.1085e-27,
#          -1.4374e-26, -2.8095e-27, -3.1848e-28, -6.5270e-28, -4.2666e-26,
#          -1.4540e-25, -1.2188e-25, -3.2572e-28, -1.8693e-30, -7.3050e-32,
#          -4.9318e-33,  7.0732e-30,  6.3448e-29,  7.1109e-27,  8.8177e-27,
#          -1.4437e-29, -6.9255e-31, -3.7352e-29, -5.7329e-30, -1.3352e-29,
#          -3.8176e-29, -5.3749e-27, -4.2584e-23],
#         [-4.1562e-23, -7.1709e-22, -4.0008e-23, -1.5025e-24, -8.1705e-26,
#          -1.2894e-25, -2.5202e-26, -2.8568e-27, -5.8549e-27, -3.8272e-25,
#          -1.3042e-24, -1.0933e-24, -2.9218e-27, -1.6768e-29, -6.5527e-31,
#          -4.4239e-32,  6.3448e-29,  5.6914e-28,  6.3786e-26,  7.9096e-26,
#          -1.2950e-28, -6.2123e-30, -3.3505e-28, -5.1425e-29, -1.1977e-28,
#          -3.4245e-28, -4.8214e-26, -3.8198e-22],
#         [-4.6581e-21, -8.0368e-20, -4.4839e-21, -1.6839e-22, -9.1572e-24,
#          -1.4451e-23, -2.8245e-24, -3.2018e-25, -6.5619e-25, -4.2894e-23,
#          -1.4617e-22, -1.2253e-22, -3.2746e-25, -1.8792e-27, -7.3440e-29,
#          -4.9581e-30,  7.1109e-27,  6.3786e-26,  7.1489e-24,  8.8648e-24,
#          -1.4514e-26, -6.9625e-28, -3.7551e-26, -5.7635e-27, -1.3424e-26,
#          -3.8380e-26, -5.4036e-24, -4.2811e-20],
#         [-5.7762e-21, -9.9658e-20, -5.5601e-21, -2.0881e-22, -1.1355e-23,
#          -1.7920e-23, -3.5024e-24, -3.9703e-25, -8.1369e-25, -5.3189e-23,
#          -1.8126e-22, -1.5194e-22, -4.0606e-25, -2.3303e-27, -9.1067e-29,
#          -6.1482e-30,  8.8177e-27,  7.9096e-26,  8.8648e-24,  1.0992e-23,
#          -1.7998e-26, -8.6336e-28, -4.6565e-26, -7.1469e-27, -1.6645e-26,
#          -4.7592e-26, -6.7006e-24, -5.3087e-20],
#         [ 9.4572e-24,  1.6317e-22,  9.1035e-24,  3.4188e-25,  1.8592e-26,
#           2.9339e-26,  5.7345e-27,  6.5005e-28,  1.3322e-27,  8.7086e-26,
#           2.9677e-25,  2.4877e-25,  6.6483e-28,  3.8154e-30,  1.4910e-31,
#           1.0066e-32, -1.4437e-29, -1.2950e-28, -1.4514e-26, -1.7998e-26,
#           2.9468e-29,  1.4136e-30,  7.6239e-29,  1.1701e-29,  2.7253e-29,
#           7.7921e-29,  1.0971e-26,  8.6918e-23],
#         [ 4.5367e-25,  7.8273e-24,  4.3670e-25,  1.6400e-26,  8.9184e-28,
#           1.4074e-27,  2.7509e-28,  3.1183e-29,  6.3908e-29,  4.1775e-27,
#           1.4236e-26,  1.1933e-26,  3.1892e-29,  1.8302e-31,  7.1525e-33,
#           4.8289e-34, -6.9255e-31, -6.2123e-30, -6.9625e-28, -8.6336e-28,
#           1.4136e-30,  6.7809e-32,  3.6572e-30,  5.6132e-31,  1.3074e-30,
#           3.7379e-30,  5.2627e-28,  4.1695e-24],
#         [ 2.4468e-23,  4.2215e-22,  2.3553e-23,  8.8452e-25,  4.8100e-26,
#           7.5908e-26,  1.4836e-26,  1.6818e-27,  3.4468e-27,  2.2531e-25,
#           7.6781e-25,  6.4362e-25,  1.7201e-27,  9.8712e-30,  3.8576e-31,
#           2.6044e-32, -3.7352e-29, -3.3505e-28, -3.7551e-26, -4.6565e-26,
#           7.6239e-29,  3.6572e-30,  1.9725e-28,  3.0274e-29,  7.0511e-29,
#           2.0160e-28,  2.8384e-26,  2.2488e-22],
#         [ 3.7554e-24,  6.4794e-23,  3.6150e-24,  1.3576e-25,  7.3826e-27,
#           1.1651e-26,  2.2771e-27,  2.5813e-28,  5.2903e-28,  3.4581e-26,
#           1.1785e-25,  9.8784e-26,  2.6400e-28,  1.5151e-30,  5.9208e-32,
#           3.9973e-33, -5.7329e-30, -5.1425e-29, -5.7635e-27, -7.1469e-27,
#           1.1701e-29,  5.6132e-31,  3.0274e-29,  4.6466e-30,  1.0822e-29,
#           3.0942e-29,  4.3565e-27,  3.4515e-23],
#         [ 8.7466e-24,  1.5091e-22,  8.4194e-24,  3.1619e-25,  1.7195e-26,
#           2.7135e-26,  5.3036e-27,  6.0120e-28,  1.2321e-27,  8.0542e-26,
#           2.7447e-25,  2.3007e-25,  6.1488e-28,  3.5287e-30,  1.3790e-31,
#           9.3099e-33, -1.3352e-29, -1.1977e-28, -1.3424e-26, -1.6645e-26,
#           2.7253e-29,  1.3074e-30,  7.0511e-29,  1.0822e-29,  2.5205e-29,
#           7.2066e-29,  1.0146e-26,  8.0387e-23],
#         [ 2.5008e-23,  4.3147e-22,  2.4072e-23,  9.0403e-25,  4.9162e-26,
#           7.7583e-26,  1.5164e-26,  1.7189e-27,  3.5228e-27,  2.3028e-25,
#           7.8475e-25,  6.5782e-25,  1.7580e-27,  1.0089e-29,  3.9427e-31,
#           2.6618e-32, -3.8176e-29, -3.4245e-28, -3.8380e-26, -4.7592e-26,
#           7.7921e-29,  3.7379e-30,  2.0160e-28,  3.0942e-29,  7.2066e-29,
#           2.0605e-28,  2.9010e-26,  2.2984e-22],
#         [ 3.5209e-21,  6.0748e-20,  3.3892e-21,  1.2728e-22,  6.9216e-24,
#           1.0923e-23,  2.1350e-24,  2.4201e-25,  4.9599e-25,  3.2422e-23,
#           1.1049e-22,  9.2616e-23,  2.4752e-25,  1.4205e-27,  5.5511e-29,
#           3.7477e-30, -5.3749e-27, -4.8214e-26, -5.4036e-24, -6.7006e-24,
#           1.0971e-26,  5.2627e-28,  2.8384e-26,  4.3565e-27,  1.0146e-26,
#           2.9010e-26,  4.0844e-24,  3.2360e-20],
#         [ 2.7895e-17,  4.8128e-16,  2.6852e-17,  1.0084e-18,  5.4838e-20,
#           8.6540e-20,  1.6915e-20,  1.9174e-21,  3.9296e-21,  2.5687e-19,
#           8.7536e-19,  7.3377e-19,  1.9610e-21,  1.1254e-23,  4.3979e-25,
#           2.9692e-26, -4.2584e-23, -3.8198e-22, -4.2811e-20, -5.3087e-20,
#           8.6918e-23,  4.1695e-24,  2.2488e-22,  3.4515e-23,  8.0387e-23,
#           2.2984e-22,  3.2360e-20,  2.5637e-16]], device='cuda:0')

# %%
def diagonality_loss(func, z):
    device = z.device
    losses = []
    for i, z in enumerate(encoded_data):
        z = z.unsqueeze(0)  # Add batch dimension
        y = func(z)  # Decode to get reconstruction
        y = y.squeeze(0)  # Remove batch dimension

        # Compute the Jacobian J of the decoder at point z
        J = torch.autograd.functional.jacobian(func, z)[0,:,0,:]
        JtJ = J.transpose(0, 1) @ J

        eye = torch.eye(JtJ.size(0), device=device)
        off_diag_mask = 1.0 - eye
        off_diag_elements = JtJ[off_diag_mask.bool()]
        loss_matrix = off_diag_elements ** 2

        losses.append(loss_matrix.mean().item())
    
    return np.mean(losses).item()

# %%
# measure isometry, scaled isometry, conformity, diagonality, (angle preservation, kl)
from metrics import isometry_loss, scaled_isometry_loss, conformality_loss

for i, lambda_iso in enumerate(lambda_isos):
    print(f"Evaluating model with lambda_iso={lambda_iso:.3f}")
    model_path = f"models/conformal_autoencoder_mnist_vec/lambda_{lambda_iso:.3f}_model_1.pth"
    model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))

    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data[:10])
        reconstruction = model.decode(encoded_data)

    isometry = isometry_loss(model.decoder, encoded_data, create_graph=False, augment=False)
    scaled_isometry = scaled_isometry_loss(model.decoder, encoded_data, create_graph=False, augment=False)
    # conformality = conformality_loss(model.decoder, encoded_data)
    diagonality = diagonality_loss(model.decoder, encoded_data)
    print(f"Isometry Loss: {isometry.item()}")
    print(f"Scaled Isometry Loss: {scaled_isometry.item()}")
    # print(f"Conformality Loss: {conformality.item()}")
    print(f"Diagonality Loss: {diagonality}")
    print("-" * 50)
# Out:
# Evaluating model with lambda_iso=0.001
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 8
#       6 model_path = f"models/conformal_autoencoder_mnist_vec/lambda_{lambda_iso:.3f}_model_1.pth"
#       7 model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
# ----> 8 model.load_state_dict(torch.load(model_path))
#      10 model.eval()
#      11 with torch.no_grad():
#
# File ~/anaconda3/envs/ML/lib/python3.13/site-packages/torch/nn/modules/module.py:2593, in Module.load_state_dict(self, state_dict, strict, assign)
#    2585         error_msgs.insert(
#    2586             0,
#    2587             "Missing key(s) in state_dict: {}. ".format(
#    2588                 ", ".join(f'"{k}"' for k in missing_keys)
#    2589             ),
#    2590         )
#    2592 if len(error_msgs) > 0:
# -> 2593     raise RuntimeError(
#    2594         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2595             self.__class__.__name__, "\n\t".join(error_msgs)
#    2596         )
#    2597     )
#    2598 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for ConformalAutoencoder:
# 	size mismatch for decoder.fc.0.weight: copying a param with shape torch.Size([64, 32]) from checkpoint, the shape in current model is torch.Size([64, 1]).
# 	size mismatch for decoder.deconv.4.weight: copying a param with shape torch.Size([8, 1, 3, 3]) from checkpoint, the shape in current model is torch.Size([8, 32, 3, 3]).
# 	size mismatch for decoder.deconv.4.bias: copying a param with shape torch.Size([1]) from checkpoint, the shape in current model is torch.Size([32]).
# 	size mismatch for model.1.fc.0.weight: copying a param with shape torch.Size([64, 32]) from checkpoint, the shape in current model is torch.Size([64, 1]).
# 	size mismatch for model.1.deconv.4.weight: copying a param with shape torch.Size([8, 1, 3, 3]) from checkpoint, the shape in current model is torch.Size([8, 32, 3, 3]).
# 	size mismatch for model.1.deconv.4.bias: copying a param with shape torch.Size([1]) from checkpoint, the shape in current model is torch.Size([32]).
