# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.datasets import make_moons, make_s_curve

from Autoencoders import ConformalAutoencoder
from helper import load_optimizer_and_scheduler, save_optimizer_and_scheduler
from data import make_half_sphere
from metrics import evaluate_conformality

random_state = 42
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super(Encoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, latent_dim)
        )
    
    def forward(self, x):
        return self.fc(x)

class Decoder(nn.Module):
    def __init__(self, latent_dim, output_dim):
        super(Decoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, output_dim)
        )
    
    def forward(self, z):
        return self.fc(z)

# %%
data, labels = make_half_sphere(n_samples=2000, noise=0.05, random_state=random_state)
data = torch.tensor(data, dtype=torch.float32).to(device)
val_data, val_labels = make_half_sphere(n_samples=1000, noise=0.05, random_state=random_state+1)
val_data = torch.tensor(val_data, dtype=torch.float32).to(device)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data[:, 0].cpu(), data[:, 1].cpu(), data[:, 2].cpu(), c=labels, s=5)
ax.set_title("Original Data in 3D")
ax.view_init(0, 180, 0)
plt.show()

# %%
# define model parameters
latent_dim = 2
input_dim = data.shape[1]
output_dim = data.shape[1]
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=False)

# %%
lambda_isos = np.logspace(-3, 3, 10)

# %%
from metrics import conformality_cosine2_loss

# %%
num_epochs = 100
# train same model multiple times to average results
num_models = 4

recon_errors = []
regularization_errors = []


for i, lambda_iso in enumerate(lambda_isos):
    recon_error = 0
    regularization = 0
    for j in range(num_models):
        print(f"Training model {j+1}/{num_models} with lambda_iso={lambda_iso:.3f}")
        
        encoder = Encoder(input_dim, latent_dim).to(device)
        decoder = Decoder(latent_dim, output_dim).to(device)
        model = ConformalAutoencoder(encoder, decoder, lambda_conf=lambda_iso).to(device)
        model.conformality_loss = conformality_cosine2_loss

        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)

        # Train the model
        model.train_model(train_dataloader, val_dataloader, batch_size=batch_size, epochs=num_epochs,
                          optimizer=optimizer, scheduler=scheduler, verbose=True)

        # Save the model and optimizer state
        model_path = f"models/conformal_angle_autoencoder_half_sphere/lambda_{lambda_iso:.3f}_model_{j+1}.pth"
        torch.save(model.state_dict(), model_path)
        print(f"Model {j+1}/{num_models} with lambda_iso={lambda_iso:.3f} trained and saved.")

        # evaluation
        model.eval()
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)
        
        recon_error += nn.MSELoss()(reconstruction, val_data).item()

        regularization += model.conformality_loss(model.decoder, encoded_data).item()
    
    recon_errors.append(recon_error/ num_models)
    regularization_errors.append(regularization/num_models)
# Out:
# Training model 1/4 with lambda_iso=0.001
# /home/maxheise/anaconda3/envs/ML/lib/python3.13/site-packages/torch/autograd/graph.py:824: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:181.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch [100/100], Loss: 0.00105466, Reconstruction Loss: 0.00104479, Conformal Loss: 0.00987036
# Epoch [100/100], Validation Loss: 0.00121885, Reconstruction Loss: 0.00120826, Conformal Loss: 0.01059276
# Model 1/4 with lambda_iso=0.001 trained and saved.
# Training model 2/4 with lambda_iso=0.001
# Epoch [100/100], Loss: 0.00099948, Reconstruction Loss: 0.00099067, Conformal Loss: 0.00881188
# Epoch [100/100], Validation Loss: 0.00112059, Reconstruction Loss: 0.00111135, Conformal Loss: 0.00924090
# Model 2/4 with lambda_iso=0.001 trained and saved.
# Training model 3/4 with lambda_iso=0.001
# Epoch [100/100], Loss: 0.00099739, Reconstruction Loss: 0.00099349, Conformal Loss: 0.00389534
# Epoch [100/100], Validation Loss: 0.00118895, Reconstruction Loss: 0.00118437, Conformal Loss: 0.00457619
# Model 3/4 with lambda_iso=0.001 trained and saved.
# Training model 4/4 with lambda_iso=0.001
# Epoch [100/100], Loss: 0.00092453, Reconstruction Loss: 0.00091815, Conformal Loss: 0.00638019
# Epoch [100/100], Validation Loss: 0.00118223, Reconstruction Loss: 0.00117546, Conformal Loss: 0.00677777
# Model 4/4 with lambda_iso=0.001 trained and saved.
# Training model 1/4 with lambda_iso=0.005
# Epoch [100/100], Loss: 0.00097603, Reconstruction Loss: 0.00096155, Conformal Loss: 0.00312093
# Epoch [100/100], Validation Loss: 0.00127786, Reconstruction Loss: 0.00125871, Conformal Loss: 0.00412638
# Model 1/4 with lambda_iso=0.005 trained and saved.
# Training model 2/4 with lambda_iso=0.005
# Epoch [100/100], Loss: 0.00097678, Reconstruction Loss: 0.00095781, Conformal Loss: 0.00408622
# Epoch [100/100], Validation Loss: 0.00124137, Reconstruction Loss: 0.00121908, Conformal Loss: 0.00480195
# Model 2/4 with lambda_iso=0.005 trained and saved.
# Training model 3/4 with lambda_iso=0.005
# Epoch [100/100], Loss: 0.00098410, Reconstruction Loss: 0.00096384, Conformal Loss: 0.00436562
# Epoch [100/100], Validation Loss: 0.00114158, Reconstruction Loss: 0.00111694, Conformal Loss: 0.00530960
# Model 3/4 with lambda_iso=0.005 trained and saved.
# Training model 4/4 with lambda_iso=0.005
# Epoch [100/100], Loss: 0.00096497, Reconstruction Loss: 0.00094665, Conformal Loss: 0.00394662
# Epoch [100/100], Validation Loss: 0.00122475, Reconstruction Loss: 0.00120467, Conformal Loss: 0.00432599
# Model 4/4 with lambda_iso=0.005 trained and saved.
# Training model 1/4 with lambda_iso=0.022
# Epoch [100/100], Loss: 0.00103774, Reconstruction Loss: 0.00099304, Conformal Loss: 0.00207499
# Epoch [100/100], Validation Loss: 0.00122784, Reconstruction Loss: 0.00117504, Conformal Loss: 0.00245058
# Model 1/4 with lambda_iso=0.022 trained and saved.
# Training model 2/4 with lambda_iso=0.022
# Epoch [100/100], Loss: 0.00102775, Reconstruction Loss: 0.00097893, Conformal Loss: 0.00226610
# Epoch [100/100], Validation Loss: 0.00120146, Reconstruction Loss: 0.00112842, Conformal Loss: 0.00339017
# Model 2/4 with lambda_iso=0.022 trained and saved.
# Training model 3/4 with lambda_iso=0.022
# Epoch [100/100], Loss: 0.00109151, Reconstruction Loss: 0.00103904, Conformal Loss: 0.00243552
# Epoch [100/100], Validation Loss: 0.00123009, Reconstruction Loss: 0.00116543, Conformal Loss: 0.00300118
# Model 3/4 with lambda_iso=0.022 trained and saved.
# Training model 4/4 with lambda_iso=0.022
# Epoch [100/100], Loss: 0.00100445, Reconstruction Loss: 0.00095577, Conformal Loss: 0.00225954
# Epoch [100/100], Validation Loss: 0.00120173, Reconstruction Loss: 0.00115096, Conformal Loss: 0.00235626
# Model 4/4 with lambda_iso=0.022 trained and saved.
# Training model 1/4 with lambda_iso=0.100
# Epoch [100/100], Loss: 0.00112536, Reconstruction Loss: 0.00099154, Conformal Loss: 0.00133817
# Epoch [100/100], Validation Loss: 0.00128589, Reconstruction Loss: 0.00114063, Conformal Loss: 0.00145257
# Model 1/4 with lambda_iso=0.100 trained and saved.
# Training model 2/4 with lambda_iso=0.100
# Epoch [100/100], Loss: 0.00110094, Reconstruction Loss: 0.00096026, Conformal Loss: 0.00140676
# Epoch [100/100], Validation Loss: 0.00127879, Reconstruction Loss: 0.00111902, Conformal Loss: 0.00159771
# Model 2/4 with lambda_iso=0.100 trained and saved.
# Training model 3/4 with lambda_iso=0.100
# Epoch [100/100], Loss: 0.00111027, Reconstruction Loss: 0.00096517, Conformal Loss: 0.00145091
# Epoch [100/100], Validation Loss: 0.00129934, Reconstruction Loss: 0.00113519, Conformal Loss: 0.00164149
# Model 3/4 with lambda_iso=0.100 trained and saved.
# Training model 4/4 with lambda_iso=0.100
# Epoch [100/100], Loss: 0.00109960, Reconstruction Loss: 0.00098011, Conformal Loss: 0.00119496
# Epoch [100/100], Validation Loss: 0.00140237, Reconstruction Loss: 0.00121918, Conformal Loss: 0.00183191
# Model 4/4 with lambda_iso=0.100 trained and saved.
# Training model 1/4 with lambda_iso=0.464
# Epoch [100/100], Loss: 0.00171968, Reconstruction Loss: 0.00110295, Conformal Loss: 0.00132869
# Epoch [100/100], Validation Loss: 0.00182790, Reconstruction Loss: 0.00128603, Conformal Loss: 0.00116742
# Model 1/4 with lambda_iso=0.464 trained and saved.
# Training model 2/4 with lambda_iso=0.464
# Epoch [100/100], Loss: 0.00144359, Reconstruction Loss: 0.00102034, Conformal Loss: 0.00091186
# Epoch [100/100], Validation Loss: 0.00186344, Reconstruction Loss: 0.00122295, Conformal Loss: 0.00137987
# Model 2/4 with lambda_iso=0.464 trained and saved.
# Training model 3/4 with lambda_iso=0.464
# Epoch [100/100], Loss: 0.00170561, Reconstruction Loss: 0.00106182, Conformal Loss: 0.00138701
# Epoch [100/100], Validation Loss: 0.00196191, Reconstruction Loss: 0.00131405, Conformal Loss: 0.00139577
# Model 3/4 with lambda_iso=0.464 trained and saved.
# Training model 4/4 with lambda_iso=0.464
# Epoch [100/100], Loss: 0.00171926, Reconstruction Loss: 0.00106831, Conformal Loss: 0.00140244
# Epoch [100/100], Validation Loss: 0.00182941, Reconstruction Loss: 0.00124915, Conformal Loss: 0.00125013
# Model 4/4 with lambda_iso=0.464 trained and saved.
# Training model 1/4 with lambda_iso=2.154
# Epoch [100/100], Loss: 0.00414325, Reconstruction Loss: 0.00150553, Conformal Loss: 0.00122432
# Epoch [100/100], Validation Loss: 0.00557160, Reconstruction Loss: 0.00206244, Conformal Loss: 0.00162881
# Model 1/4 with lambda_iso=2.154 trained and saved.
# Training model 2/4 with lambda_iso=2.154
# Epoch [100/100], Loss: 0.00347519, Reconstruction Loss: 0.00135407, Conformal Loss: 0.00098454
# Epoch [100/100], Validation Loss: 0.00404081, Reconstruction Loss: 0.00163027, Conformal Loss: 0.00111887
# Model 2/4 with lambda_iso=2.154 trained and saved.
# Training model 3/4 with lambda_iso=2.154
# Epoch [100/100], Loss: 0.00303397, Reconstruction Loss: 0.00133881, Conformal Loss: 0.00078682
# Epoch [100/100], Validation Loss: 0.00414543, Reconstruction Loss: 0.00160111, Conformal Loss: 0.00118097
# Model 3/4 with lambda_iso=2.154 trained and saved.
# Training model 4/4 with lambda_iso=2.154
# Epoch [100/100], Loss: 0.00357720, Reconstruction Loss: 0.00141785, Conformal Loss: 0.00100228
# Epoch [100/100], Validation Loss: 0.00380933, Reconstruction Loss: 0.00149204, Conformal Loss: 0.00107559
# Model 4/4 with lambda_iso=2.154 trained and saved.
# Training model 1/4 with lambda_iso=10.000
# Epoch [100/100], Loss: 0.01982298, Reconstruction Loss: 0.01212392, Conformal Loss: 0.00076991
# Epoch [100/100], Validation Loss: 0.02386719, Reconstruction Loss: 0.01637652, Conformal Loss: 0.00074907
# Model 1/4 with lambda_iso=10.000 trained and saved.
# Training model 2/4 with lambda_iso=10.000
# Epoch [100/100], Loss: 0.01629295, Reconstruction Loss: 0.00329343, Conformal Loss: 0.00129995
# Epoch [100/100], Validation Loss: 0.01726713, Reconstruction Loss: 0.00382766, Conformal Loss: 0.00134395
# Model 2/4 with lambda_iso=10.000 trained and saved.
# Training model 3/4 with lambda_iso=10.000
# Epoch [100/100], Loss: 0.01352704, Reconstruction Loss: 0.00276385, Conformal Loss: 0.00107632
# Epoch [100/100], Validation Loss: 0.01605182, Reconstruction Loss: 0.00327763, Conformal Loss: 0.00127742
# Model 3/4 with lambda_iso=10.000 trained and saved.
# Training model 4/4 with lambda_iso=10.000
# Epoch [100/100], Loss: 0.01255533, Reconstruction Loss: 0.00272824, Conformal Loss: 0.00098271
# Epoch [100/100], Validation Loss: 0.01545119, Reconstruction Loss: 0.00349218, Conformal Loss: 0.00119590
# Model 4/4 with lambda_iso=10.000 trained and saved.
# Training model 1/4 with lambda_iso=46.416
# Epoch [100/100], Loss: 0.03960678, Reconstruction Loss: 0.00826803, Conformal Loss: 0.00067517
# Epoch [100/100], Validation Loss: 0.03347509, Reconstruction Loss: 0.00818501, Conformal Loss: 0.00054486
# Model 1/4 with lambda_iso=46.416 trained and saved.
# Training model 2/4 with lambda_iso=46.416
# Epoch [100/100], Loss: 0.05310839, Reconstruction Loss: 0.00973965, Conformal Loss: 0.00093435
# Epoch [100/100], Validation Loss: 0.05324730, Reconstruction Loss: 0.01027722, Conformal Loss: 0.00092576
# Model 2/4 with lambda_iso=46.416 trained and saved.
# Training model 3/4 with lambda_iso=46.416
# Epoch [100/100], Loss: 0.04253896, Reconstruction Loss: 0.00688851, Conformal Loss: 0.00076807
# Epoch [100/100], Validation Loss: 0.05241606, Reconstruction Loss: 0.00861524, Conformal Loss: 0.00094366
# Model 3/4 with lambda_iso=46.416 trained and saved.
# Training model 4/4 with lambda_iso=46.416
# Epoch [100/100], Loss: 0.05575529, Reconstruction Loss: 0.00725610, Conformal Loss: 0.00104488
# Epoch [100/100], Validation Loss: 0.05727009, Reconstruction Loss: 0.00916358, Conformal Loss: 0.00103642
# Model 4/4 with lambda_iso=46.416 trained and saved.
# Training model 1/4 with lambda_iso=215.443
# Epoch [100/100], Loss: 0.11489771, Reconstruction Loss: 0.01255647, Conformal Loss: 0.00047503
# Epoch [100/100], Validation Loss: 0.11937314, Reconstruction Loss: 0.01191918, Conformal Loss: 0.00049876
# Model 1/4 with lambda_iso=215.443 trained and saved.
# Training model 2/4 with lambda_iso=215.443
# Epoch [100/100], Loss: 0.10665694, Reconstruction Loss: 0.01651362, Conformal Loss: 0.00041841
# Epoch [100/100], Validation Loss: 0.10712624, Reconstruction Loss: 0.01975955, Conformal Loss: 0.00040552
# Model 2/4 with lambda_iso=215.443 trained and saved.
# Training model 3/4 with lambda_iso=215.443
# Epoch [100/100], Loss: 0.22950813, Reconstruction Loss: 0.01874790, Conformal Loss: 0.00097826
# Epoch [100/100], Validation Loss: 0.16495182, Reconstruction Loss: 0.01911889, Conformal Loss: 0.00067690
# Model 3/4 with lambda_iso=215.443 trained and saved.
# Training model 4/4 with lambda_iso=215.443
# Epoch [100/100], Loss: 0.10132488, Reconstruction Loss: 0.03274881, Conformal Loss: 0.00031830
# Epoch [100/100], Validation Loss: 0.08783957, Reconstruction Loss: 0.03366484, Conformal Loss: 0.00025146
# Model 4/4 with lambda_iso=215.443 trained and saved.
# Training model 1/4 with lambda_iso=1000.000
# Epoch [100/100], Loss: 0.54069686, Reconstruction Loss: 0.01292358, Conformal Loss: 0.00052777
# Epoch [100/100], Validation Loss: 0.61305690, Reconstruction Loss: 0.01455362, Conformal Loss: 0.00059850
# Model 1/4 with lambda_iso=1000.000 trained and saved.
# Training model 2/4 with lambda_iso=1000.000
# Epoch [100/100], Loss: 0.56567723, Reconstruction Loss: 0.01713413, Conformal Loss: 0.00054854
# Epoch [100/100], Validation Loss: 0.62032473, Reconstruction Loss: 0.01764914, Conformal Loss: 0.00060268
# Model 2/4 with lambda_iso=1000.000 trained and saved.
# Training model 3/4 with lambda_iso=1000.000
# Epoch [100/100], Loss: 0.53810257, Reconstruction Loss: 0.04174388, Conformal Loss: 0.00049636
# Epoch [100/100], Validation Loss: 0.50773275, Reconstruction Loss: 0.04313455, Conformal Loss: 0.00046460
# Model 3/4 with lambda_iso=1000.000 trained and saved.
# Training model 4/4 with lambda_iso=1000.000
# Epoch [100/100], Loss: 0.24925703, Reconstruction Loss: 0.03179827, Conformal Loss: 0.00021746
# Epoch [100/100], Validation Loss: 0.29096708, Reconstruction Loss: 0.04238367, Conformal Loss: 0.00024858
# Model 4/4 with lambda_iso=1000.000 trained and saved.

# %%
plt.plot(lambda_isos, recon_errors, label='Reconstruction Error')
plt.plot(lambda_isos, regularization_errors, label='Regularization Error')
plt.ylim(0, 0.06)
plt.xscale('log')
plt.xlabel('Lambda (log scale)')
plt.ylabel('Error')
plt.title('Reconstruction and Regularization Errors vs Lambda')
plt.legend()
plt.show()

# %%
# plot samples and latent space at different lambdas
fig, axs = plt.subplots(2, 10, figsize=(40, 8), subplot_kw=dict(projection='3d'))
for i, lambda_iso in enumerate(lambda_isos):
    model_path = f"models/conformal_angle_autoencoder_half_sphere/lambda_{lambda_iso:.3f}_model_2.pth"
    model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    axs[0, i].scatter(encoded_data[:, 0].cpu(), encoded_data[:, 1].cpu(), c=val_labels, s=5)
    axs[0, i].set_title(f'Latent Space (λ={lambda_iso:.3f})')
    axs[0, i].view_init(90, 90, 0)
    # axs[0, i].set_xticks([])
    # axs[0, i].set_yticks([])
    #plot 3d data
    axs[1, i].scatter(reconstruction[:, 0].cpu(), reconstruction[:, 1].cpu(), reconstruction[:, 2].cpu(), c=val_labels, s=5)
    axs[1, i].set_title(f'Reconstruction (λ={lambda_iso:.3f})')

# %%
fig, axs = plt.subplots(2, 10, figsize=(40, 8), subplot_kw=dict(projection='3d'))
for i, lambda_iso in enumerate(lambda_isos):
    model_path = f"models/conformal_angle_autoencoder_half_sphere/lambda_{lambda_iso:.3f}_model_1.pth"
    model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    trace_vals = np.zeros_like(encoded_data[:, 0].cpu())
    for j, z in enumerate(encoded_data):
        z = z.unsqueeze(0)  # Add batch dimension
        y = model.decode(z)  # Decode to get reconstruction
        y = y.squeeze(0)  # Remove batch dimension

        # Compute the Jacobian J of the decoder at point z
        J = torch.autograd.functional.jacobian(model.decode, z)[0,:,0,:]

        # Compute the trace of J^T J
        JtJ = J.T @ J
        trace_JtJ = torch.trace(JtJ)

        # Store the trace value as a label for the point
        trace_vals[j] = trace_JtJ.item() / JtJ.shape[0]  # Normalize by the number of dimensions

    p = axs[0, i].scatter(encoded_data[:, 0].cpu(), encoded_data[:, 1].cpu(), c=trace_vals, s=5)
    plt.colorbar(p)
    axs[0, i].set_title(f'Latent Space (λ={lambda_iso:.3f})')
    axs[0, i].view_init(90, 90, 0)
    # axs[0, i].set_xticks([])
    # axs[0, i].set_yticks([])
    #plot 3d data
    p = axs[1, i].scatter(reconstruction[:, 0].cpu(), reconstruction[:, 1].cpu(), reconstruction[:, 2].cpu(), c=trace_vals, s=5)
    plt.colorbar(p)
    axs[1, i].set_title(f'Reconstruction (λ={lambda_iso:.3f})')

# %%
statses = []
for i, lambda_iso in enumerate(lambda_isos):
    model_path = f"models/conformal_angle_autoencoder_half_sphere/lambda_{lambda_iso:.3f}_model_1.pth"
    model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    statses.append(evaluate_conformality(model, data))

df = pd.DataFrame(statses, index=lambda_isos)
# styled_df = df.style.highlight_min(color='green').highlight_max(color='coral')

# %%
styled_df = df.style \
    .background_gradient(subset=[
            'reconstruction_error',
            'diagonal_gini',
            'lambda_std',
            'lambda_std_normed',
            'off_diag_mean',
            'off_diag_norm',
            'off_diag_mean_normed',
            'off_diag_norm_normed',
            'jTj_minus_lambdaI_mean',
            'jTj_minus_lambdaI_norm',
            'jTj_minus_lambdaI_mean_normed',
            'jTj_minus_lambdaI_norm_normed',
            'determinant_vs_estimate_std',
            ], cmap='Reds') \
    .background_gradient(subset=[
        'determinant_vs_estimate_mean'
    ], cmap='Greens')\
    .background_gradient(subset=[
        'lambda_mean',
        'latent_std',
        'latent_std_max',
        'latent_std_min',
        'latent_norm',
    ], cmap='Blues')

styled_df
# Out:
# <style type="text/css">
# #T_aed71_row0_col0, #T_aed71_row2_col0, #T_aed71_row3_col0, #T_aed71_row6_col3, #T_aed71_row6_col4, #T_aed71_row8_col1, #T_aed71_row8_col5, #T_aed71_row8_col6, #T_aed71_row8_col7, #T_aed71_row8_col8, #T_aed71_row8_col9, #T_aed71_row8_col10, #T_aed71_row8_col11, #T_aed71_row8_col12, #T_aed71_row8_col14 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_aed71_row0_col1, #T_aed71_row0_col5, #T_aed71_row0_col6, #T_aed71_row0_col7, #T_aed71_row0_col8, #T_aed71_row0_col9, #T_aed71_row0_col10, #T_aed71_row0_col11, #T_aed71_row0_col12, #T_aed71_row0_col14, #T_aed71_row1_col3, #T_aed71_row2_col4, #T_aed71_row9_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_aed71_row0_col2 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_aed71_row0_col3 {
#   background-color: #ce1a1e;
#   color: #f1f1f1;
# }
# #T_aed71_row0_col4 {
#   background-color: #e43027;
#   color: #f1f1f1;
# }
# #T_aed71_row0_col13 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_aed71_row0_col15, #T_aed71_row0_col16, #T_aed71_row0_col17, #T_aed71_row0_col18, #T_aed71_row1_col17, #T_aed71_row8_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_aed71_row1_col0, #T_aed71_row8_col3, #T_aed71_row9_col7, #T_aed71_row9_col8 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_aed71_row1_col1 {
#   background-color: #fb7555;
#   color: #f1f1f1;
# }
# #T_aed71_row1_col2, #T_aed71_row6_col15, #T_aed71_row6_col16, #T_aed71_row6_col17, #T_aed71_row6_col18 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_aed71_row1_col4 {
#   background-color: #8a0812;
#   color: #f1f1f1;
# }
# #T_aed71_row1_col5, #T_aed71_row1_col6 {
#   background-color: #f96044;
#   color: #f1f1f1;
# }
# #T_aed71_row1_col7, #T_aed71_row1_col8 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_aed71_row1_col9 {
#   background-color: #f6583e;
#   color: #f1f1f1;
# }
# #T_aed71_row1_col10 {
#   background-color: #f7593f;
#   color: #f1f1f1;
# }
# #T_aed71_row1_col11 {
#   background-color: #fb7a5a;
#   color: #f1f1f1;
# }
# #T_aed71_row1_col12 {
#   background-color: #fb7b5b;
#   color: #f1f1f1;
# }
# #T_aed71_row1_col13 {
#   background-color: #2f984f;
#   color: #f1f1f1;
# }
# #T_aed71_row1_col14 {
#   background-color: #fc8565;
#   color: #f1f1f1;
# }
# #T_aed71_row1_col15 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_aed71_row1_col16 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_aed71_row1_col18 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_aed71_row2_col1 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_aed71_row2_col2 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_aed71_row2_col3 {
#   background-color: #e83429;
#   color: #f1f1f1;
# }
# #T_aed71_row2_col5, #T_aed71_row2_col6 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_aed71_row2_col7, #T_aed71_row2_col8 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_aed71_row2_col9 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_aed71_row2_col10 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_aed71_row2_col11, #T_aed71_row2_col12 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_aed71_row2_col13 {
#   background-color: #137d39;
#   color: #f1f1f1;
# }
# #T_aed71_row2_col14, #T_aed71_row4_col1 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_aed71_row2_col15 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_aed71_row2_col16, #T_aed71_row9_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_aed71_row2_col17 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_aed71_row2_col18 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_aed71_row3_col1 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_aed71_row3_col2, #T_aed71_row8_col16 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_aed71_row3_col3 {
#   background-color: #f0402f;
#   color: #f1f1f1;
# }
# #T_aed71_row3_col4 {
#   background-color: #860811;
#   color: #f1f1f1;
# }
# #T_aed71_row3_col5, #T_aed71_row3_col6, #T_aed71_row4_col11, #T_aed71_row4_col12, #T_aed71_row5_col7, #T_aed71_row5_col8 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_aed71_row3_col7, #T_aed71_row3_col8, #T_aed71_row4_col5, #T_aed71_row4_col6 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_aed71_row3_col9 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_aed71_row3_col10 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_aed71_row3_col11, #T_aed71_row4_col9, #T_aed71_row5_col12 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_aed71_row3_col12, #T_aed71_row4_col10 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_aed71_row3_col13, #T_aed71_row5_col13 {
#   background-color: #006428;
#   color: #f1f1f1;
# }
# #T_aed71_row3_col14 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_aed71_row3_col15 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_aed71_row3_col16 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_aed71_row3_col17 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_aed71_row3_col18 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_aed71_row4_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_aed71_row4_col2 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_aed71_row4_col3 {
#   background-color: #e02c26;
#   color: #f1f1f1;
# }
# #T_aed71_row4_col4 {
#   background-color: #7e0610;
#   color: #f1f1f1;
# }
# #T_aed71_row4_col7, #T_aed71_row4_col8, #T_aed71_row5_col9 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_aed71_row4_col13 {
#   background-color: #005c25;
#   color: #f1f1f1;
# }
# #T_aed71_row4_col14 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_aed71_row4_col15 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_aed71_row4_col16 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_aed71_row4_col17 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_aed71_row4_col18 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_aed71_row5_col0, #T_aed71_row7_col3 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_aed71_row5_col1 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_aed71_row5_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_aed71_row5_col3 {
#   background-color: #fc8f6f;
#   color: #000000;
# }
# #T_aed71_row5_col4 {
#   background-color: #940b13;
#   color: #f1f1f1;
# }
# #T_aed71_row5_col5, #T_aed71_row5_col6 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_aed71_row5_col10 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_aed71_row5_col11 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_aed71_row5_col14 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_aed71_row5_col15 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_aed71_row5_col16 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_aed71_row5_col17 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_aed71_row5_col18 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_aed71_row6_col0 {
#   background-color: #8e0912;
#   color: #f1f1f1;
# }
# #T_aed71_row6_col1, #T_aed71_row6_col7, #T_aed71_row6_col8, #T_aed71_row6_col11, #T_aed71_row6_col12 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_aed71_row6_col2, #T_aed71_row7_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_aed71_row6_col5, #T_aed71_row6_col6, #T_aed71_row6_col9, #T_aed71_row6_col10, #T_aed71_row9_col5, #T_aed71_row9_col6 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_aed71_row6_col13 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_aed71_row6_col14 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_aed71_row7_col0 {
#   background-color: #ef3c2c;
#   color: #f1f1f1;
# }
# #T_aed71_row7_col1, #T_aed71_row9_col3, #T_aed71_row9_col9, #T_aed71_row9_col10 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_aed71_row7_col4 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_aed71_row7_col5, #T_aed71_row7_col6, #T_aed71_row7_col9, #T_aed71_row7_col10, #T_aed71_row7_col14 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_aed71_row7_col7, #T_aed71_row7_col8 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_aed71_row7_col11, #T_aed71_row7_col12 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_aed71_row7_col13 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_aed71_row7_col15, #T_aed71_row9_col17 {
#   backgro

# %%
def diagonality_loss(func, z):
    device = z.device
    losses = []
    for i, z in enumerate(encoded_data):
        z = z.unsqueeze(0)  # Add batch dimension
        y = func(z)  # Decode to get reconstruction
        y = y.squeeze(0)  # Remove batch dimension

        # Compute the Jacobian J of the decoder at point z
        J = torch.autograd.functional.jacobian(func, z)[0,:,0,:]
        JtJ = J.transpose(0, 1) @ J

        eye = torch.eye(JtJ.size(0), device=device)
        off_diag_mask = 1.0 - eye
        off_diag_elements = JtJ[off_diag_mask.bool()]
        loss_matrix = off_diag_elements ** 2

        losses.append(loss_matrix.mean().item())
    
    return np.mean(losses).item()

# %%
# measure isometry, scaled isometry, conformity, diagonality, (angle preservation, kl)
from metrics import isometry_loss, scaled_isometry_loss, conformality_loss

for i, lambda_iso in enumerate(lambda_isos):
    print(f"Evaluating model with lambda_iso={lambda_iso:.3f}")
    model_path = f"models/conformal_angle_autoencoder_half_sphere/lambda_{lambda_iso:.3f}_model_2.pth"
    model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))

    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    isometry = isometry_loss(model.decoder, encoded_data, create_graph=False, augment=False)
    scaled_isometry = scaled_isometry_loss(model.decoder, encoded_data, create_graph=False, augment=False)
    conformality = conformality_loss(model.decoder, encoded_data)
    diagonality = diagonality_loss(model.decoder, encoded_data)
    print(f"Isometry Loss: {isometry.item()}")
    print(f"Scaled Isometry Loss: {scaled_isometry.item()}")
    print(f"Conformality Loss: {conformality.item()}")
    print(f"Diagonality Loss: {diagonality}")
    print("-" * 50)
# Out:
# Evaluating model with lambda_iso=0.001
# Isometry Loss: 0.04176812246441841
# Scaled Isometry Loss: 0.5978323817253113
# Conformality Loss: 12.928333282470703
# Diagonality Loss: 0.008127921544648207
# --------------------------------------------------
# Evaluating model with lambda_iso=0.005
# Isometry Loss: 0.049997057765722275
# Scaled Isometry Loss: 0.6001989841461182
# Conformality Loss: 5.1667022705078125
# Diagonality Loss: 0.0027751434672906258
# --------------------------------------------------
# Evaluating model with lambda_iso=0.022
# Isometry Loss: 0.105283223092556
# Scaled Isometry Loss: 0.5800262093544006
# Conformality Loss: 1.7951844930648804
# Diagonality Loss: 0.0010458836656593437
# --------------------------------------------------
# Evaluating model with lambda_iso=0.100
# Isometry Loss: 0.15836235880851746
# Scaled Isometry Loss: 0.5943833589553833
# Conformality Loss: 0.7995137572288513
# Diagonality Loss: 0.00037660581105460587
# --------------------------------------------------
# Evaluating model with lambda_iso=0.464
# Isometry Loss: 0.3539578318595886
# Scaled Isometry Loss: 0.5590348839759827
# Conformality Loss: 0.1893867701292038
# Diagonality Loss: 0.00012294193220651887
# --------------------------------------------------
# Evaluating model with lambda_iso=2.154
# Isometry Loss: 0.5643053650856018
# Scaled Isometry Loss: 0.593677282333374
# Conformality Loss: 0.03276877850294113
# Diagonality Loss: 1.877178372320799e-05
# --------------------------------------------------
# Evaluating model with lambda_iso=10.000
# Isometry Loss: 0.7381882071495056
# Scaled Isometry Loss: 0.5667769312858582
# Conformality Loss: 0.003938800189644098
# Diagonality Loss: 2.1902686563150237e-06
# --------------------------------------------------
# Evaluating model with lambda_iso=46.416
# Isometry Loss: 0.8434925675392151
# Scaled Isometry Loss: 0.5882222056388855
# Conformality Loss: 0.000649593654088676
# Diagonality Loss: 3.7273634405341905e-07
# --------------------------------------------------
# Evaluating model with lambda_iso=215.443
# Isometry Loss: 0.9111355543136597
# Scaled Isometry Loss: 0.5323522686958313
# Conformality Loss: 8.988273475551978e-05
# Diagonality Loss: 4.4342902410682446e-08
# --------------------------------------------------
# Evaluating model with lambda_iso=1000.000
# Isometry Loss: 0.89223313331604
# Scaled Isometry Loss: 0.4879964590072632
# Conformality Loss: 6.824685988249257e-05
# Diagonality Loss: 4.308350116753054e-08
# --------------------------------------------------
