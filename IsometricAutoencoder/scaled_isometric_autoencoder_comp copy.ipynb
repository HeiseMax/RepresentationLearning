# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

from sklearn.datasets import make_moons, make_s_curve

from Autoencoders import ScaledIsometricAutoencoder
from helper import load_optimizer_and_scheduler, save_optimizer_and_scheduler
from data import make_half_sphere

random_state = 42
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super(Encoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, latent_dim)
        )
    
    def forward(self, x):
        return self.fc(x)

class Decoder(nn.Module):
    def __init__(self, latent_dim, output_dim):
        super(Decoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, output_dim)
        )
    
    def forward(self, z):
        return self.fc(z)

# %%
data, labels = make_s_curve(n_samples=2000, noise=0.05, random_state=random_state)
data = torch.tensor(data, dtype=torch.float32).to(device)
val_data, val_labels = make_s_curve(n_samples=1000, noise=0.05, random_state=random_state+1)
val_data = torch.tensor(val_data, dtype=torch.float32).to(device)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data[:, 0].cpu(), data[:, 1].cpu(), data[:, 2].cpu(), c=labels, s=5)
ax.set_title("Original Data in 3D")
ax.view_init(0, 180, 0)
plt.show()

# %%
# define model parameters
latent_dim = 2
input_dim = data.shape[1]
output_dim = data.shape[1]
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=False)

# %%
lambda_isos = np.logspace(-3, 2, 10)

# %%
num_epochs = 100
# train same model multiple times to average results
num_models = 4

recon_errors = []
regularization_errors = []


for i, lambda_iso in enumerate(lambda_isos):
    recon_error = 0
    regularization = 0
    for j in range(num_models):
        print(f"Training model {j+1}/{num_models} with lambda_iso={lambda_iso:.3f}")
        
        encoder = Encoder(input_dim, latent_dim).to(device)
        decoder = Decoder(latent_dim, output_dim).to(device)
        model = ScaledIsometricAutoencoder(encoder, decoder, lambda_iso=lambda_iso).to(device)

        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)

        # Train the model
        model.train_model(train_dataloader, val_dataloader, batch_size=batch_size, epochs=num_epochs,
                          optimizer=optimizer, scheduler=scheduler, verbose=True)

        # Save the model and optimizer state
        model_path = f"models/scaled_isometric_autoencoder_s_curve/lambda_{lambda_iso:.3f}_model_{j+1}.pth"
        torch.save(model.state_dict(), model_path)
        print(f"Model {j+1}/{num_models} with lambda_iso={lambda_iso:.3f} trained and saved.")

        # evaluation
        model.eval()
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)
        
        recon_error += nn.MSELoss()(reconstruction, val_data).item()

        regularization += model.scaled_isometry_loss(model.decoder, encoded_data, create_graph=False, augment=False).item()
    
    recon_errors.append(recon_error/ num_models)
    regularization_errors.append(regularization/num_models)
# Out:
# Training model 1/4 with lambda_iso=0.001
# /home/maxheise/anaconda3/envs/ML/lib/python3.13/site-packages/torch/autograd/graph.py:824: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:181.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch [100/100], Loss: 0.00298661, Reconstruction Loss: 0.00215867, Isometric Loss: 0.82794172
# Epoch [100/100], Validation Loss: 0.00398187, Reconstruction Loss: 0.00318517, Isometric Loss: 0.79669893
# Model 1/4 with lambda_iso=0.001 trained and saved.
# Training model 2/4 with lambda_iso=0.001
# Epoch [100/100], Loss: 0.00380780, Reconstruction Loss: 0.00289008, Isometric Loss: 0.91772020
# Epoch [100/100], Validation Loss: 0.00472777, Reconstruction Loss: 0.00380206, Isometric Loss: 0.92571312
# Model 2/4 with lambda_iso=0.001 trained and saved.
# Training model 3/4 with lambda_iso=0.001
# Epoch [100/100], Loss: 0.00284503, Reconstruction Loss: 0.00204134, Isometric Loss: 0.80369180
# Epoch [100/100], Validation Loss: 0.00311733, Reconstruction Loss: 0.00235094, Isometric Loss: 0.76639062
# Model 3/4 with lambda_iso=0.001 trained and saved.
# Training model 4/4 with lambda_iso=0.001
# Epoch [100/100], Loss: 0.00343358, Reconstruction Loss: 0.00261666, Isometric Loss: 0.81692326
# Epoch [100/100], Validation Loss: 0.00402520, Reconstruction Loss: 0.00320606, Isometric Loss: 0.81913173
# Model 4/4 with lambda_iso=0.001 trained and saved.
# Training model 1/4 with lambda_iso=0.004
# Epoch [100/100], Loss: 0.00375796, Reconstruction Loss: 0.00172804, Isometric Loss: 0.56483674
# Epoch [100/100], Validation Loss: 0.00407136, Reconstruction Loss: 0.00218546, Isometric Loss: 0.52476239
# Model 1/4 with lambda_iso=0.004 trained and saved.
# Training model 2/4 with lambda_iso=0.004
# Epoch [100/100], Loss: 0.00495308, Reconstruction Loss: 0.00228581, Isometric Loss: 0.74218214
# Epoch [100/100], Validation Loss: 0.00561788, Reconstruction Loss: 0.00300601, Isometric Loss: 0.72676587
# Model 2/4 with lambda_iso=0.004 trained and saved.
# Training model 3/4 with lambda_iso=0.004
# Epoch [100/100], Loss: 0.00438182, Reconstruction Loss: 0.00213208, Isometric Loss: 0.62600416
# Epoch [100/100], Validation Loss: 0.00479298, Reconstruction Loss: 0.00253552, Isometric Loss: 0.62815160
# Model 3/4 with lambda_iso=0.004 trained and saved.
# Training model 4/4 with lambda_iso=0.004
# Epoch [100/100], Loss: 0.00436323, Reconstruction Loss: 0.00207630, Isometric Loss: 0.63635290
# Epoch [100/100], Validation Loss: 0.00506655, Reconstruction Loss: 0.00266729, Isometric Loss: 0.66760695
# Model 4/4 with lambda_iso=0.004 trained and saved.
# Training model 1/4 with lambda_iso=0.013
# Epoch [100/100], Loss: 0.01111780, Reconstruction Loss: 0.00287548, Isometric Loss: 0.63817269
# Epoch [100/100], Validation Loss: 0.01278003, Reconstruction Loss: 0.00429839, Isometric Loss: 0.65670270
# Model 1/4 with lambda_iso=0.013 trained and saved.
# Training model 2/4 with lambda_iso=0.013
# Epoch [100/100], Loss: 0.00973476, Reconstruction Loss: 0.00231333, Isometric Loss: 0.57461488
# Epoch [100/100], Validation Loss: 0.01005325, Reconstruction Loss: 0.00242337, Isometric Loss: 0.59075403
# Model 2/4 with lambda_iso=0.013 trained and saved.
# Training model 3/4 with lambda_iso=0.013
# Epoch [100/100], Loss: 0.01059940, Reconstruction Loss: 0.00242160, Isometric Loss: 0.63317686
# Epoch [100/100], Validation Loss: 0.01194567, Reconstruction Loss: 0.00362031, Isometric Loss: 0.64460266
# Model 3/4 with lambda_iso=0.013 trained and saved.
# Training model 4/4 with lambda_iso=0.013
# Epoch [100/100], Loss: 0.00988958, Reconstruction Loss: 0.00232902, Isometric Loss: 0.58538687
# Epoch [100/100], Validation Loss: 0.00951746, Reconstruction Loss: 0.00232734, Isometric Loss: 0.55670494
# Model 4/4 with lambda_iso=0.013 trained and saved.
# Training model 1/4 with lambda_iso=0.046
# Epoch [100/100], Loss: 0.03055272, Reconstruction Loss: 0.00415816, Isometric Loss: 0.56865346
# Epoch [100/100], Validation Loss: 0.03107651, Reconstruction Loss: 0.00437730, Isometric Loss: 0.57521683
# Model 1/4 with lambda_iso=0.046 trained and saved.
# Training model 2/4 with lambda_iso=0.046
# Epoch [100/100], Loss: 0.03106661, Reconstruction Loss: 0.00348295, Isometric Loss: 0.59427190
# Epoch [100/100], Validation Loss: 0.03226397, Reconstruction Loss: 0.00409277, Isometric Loss: 0.60693026
# Model 2/4 with lambda_iso=0.046 trained and saved.
# Training model 3/4 with lambda_iso=0.046
# Epoch [100/100], Loss: 0.03179127, Reconstruction Loss: 0.00414755, Isometric Loss: 0.59556597
# Epoch [100/100], Validation Loss: 0.03188781, Reconstruction Loss: 0.00452418, Isometric Loss: 0.58953148
# Model 3/4 with lambda_iso=0.046 trained and saved.
# Training model 4/4 with lambda_iso=0.046
# Epoch [100/100], Loss: 0.03172718, Reconstruction Loss: 0.00337468, Isometric Loss: 0.61083609
# Epoch [100/100], Validation Loss: 0.03100091, Reconstruction Loss: 0.00326402, Isometric Loss: 0.59757316
# Model 4/4 with lambda_iso=0.046 trained and saved.
# Training model 1/4 with lambda_iso=0.167
# Epoch [100/100], Loss: 0.09875112, Reconstruction Loss: 0.00520751, Isometric Loss: 0.56077921
# Epoch [100/100], Validation Loss: 0.09772515, Reconstruction Loss: 0.00566104, Isometric Loss: 0.55190980
# Model 1/4 with lambda_iso=0.167 trained and saved.
# Training model 2/4 with lambda_iso=0.167
# Epoch [100/100], Loss: 0.09577151, Reconstruction Loss: 0.00623959, Isometric Loss: 0.53672975
# Epoch [100/100], Validation Loss: 0.09953506, Reconstruction Loss: 0.00632485, Isometric Loss: 0.55878055
# Model 2/4 with lambda_iso=0.167 trained and saved.
# Training model 3/4 with lambda_iso=0.167
# Epoch [100/100], Loss: 0.10270119, Reconstruction Loss: 0.00588200, Isometric Loss: 0.58041584
# Epoch [100/100], Validation Loss: 0.10324857, Reconstruction Loss: 0.00657641, Isometric Loss: 0.57953441
# Model 3/4 with lambda_iso=0.167 trained and saved.
# Training model 4/4 with lambda_iso=0.167
# Epoch [100/100], Loss: 0.09596267, Reconstruction Loss: 0.00514829, Isometric Loss: 0.54441786
# Epoch [100/100], Validation Loss: 0.09758306, Reconstruction Loss: 0.00577711, Isometric Loss: 0.55036223
# Model 4/4 with lambda_iso=0.167 trained and saved.
# Training model 1/4 with lambda_iso=0.599
# Epoch [100/100], Loss: 0.34424323, Reconstruction Loss: 0.01289224, Isometric Loss: 0.55272675
# Epoch [100/100], Validation Loss: 0.32597855, Reconstruction Loss: 0.01112819, Isometric Loss: 0.52520210
# Model 1/4 with lambda_iso=0.599 trained and saved.
# Training model 2/4 with lambda_iso=0.599
# Epoch [100/100], Loss: 0.30993411, Reconstruction Loss: 0.00313660, Isometric Loss: 0.51176912
# Epoch [100/100], Validation Loss: 0.30366364, Reconstruction Loss: 0.00317680, Isometric Loss: 0.50124222
# Model 2/4 with lambda_iso=0.599 trained and saved.
# Training model 3/4 with lambda_iso=0.599
# Epoch [100/100], Loss: 0.32746929, Reconstruction Loss: 0.01093294, Isometric Loss: 0.52801442
# Epoch [100/100], Validation Loss: 0.32292202, Reconstruction Loss: 0.01153993, Isometric Loss: 0.51941663
# Model 3/4 with lambda_iso=0.599 trained and saved.
# Training model 4/4 with lambda_iso=0.599
# Epoch [100/100], Loss: 0.30747229, Reconstruction Loss: 0.00242608, Isometric Loss: 0.50884777
# Epoch [100/100], Validation Loss: 0.31678984, Reconstruction Loss: 0.00252297, Isometric Loss: 0.52422869
# Model 4/4 with lambda_iso=0.599 trained and saved.
# Training model 1/4 with lambda_iso=2.154
# Epoch [100/100], Loss: 1.15355003, Reconstruction Loss: 0.02216228, Isometric Loss: 0.52514362
# Epoch [100/100], Validation Loss: 1.06348968, Reconstruction Loss: 0.02284851, Isometric Loss: 0.48302284
# Model 1/4 with lambda_iso=2.154 trained and saved.
# Training model 2/4 with lambda_iso=2.154
# Epoch [100/100], Loss: 1.09723759, Reconstruction Loss: 0.01618859, Isometric Loss: 0.50177842
# Epoch [100/100], Validation Loss: 1.07690883, Reconstruction Loss: 0.02663894, Isometric Loss: 0.48749208
# Model 2/4 with lambda_iso=2.154 trained and saved.
# Training model 3/4 with lambda_iso=2.154
# Epoch [100/100], Loss: 1.13013673, Reconstruction Loss: 0.00367191, Isometric Loss: 0.52285874
# Epoch [100/100], Validation Loss: 1.12370706, Reconstruction Loss: 0.00337588, Isometric Loss: 0.52001166
# Model 3/4 with lambda_iso=2.154 trained and saved.
# Training model 4/4 with lambda_iso=2.154
# Epoch [100/100], Loss: 1.09750187, Reconstruction Loss: 0.01974501, Isometric Loss: 0.50025040
# Epoch [100/100], Validation Loss: 1.08628964, Reconstruction Loss: 0.01978394, Isometric Loss: 0.49502808
# Model 4/4 with lambda_iso=2.154 trained and saved.
# Training model 1/4 with lambda_iso=7.743
# Epoch [100/100], Loss: 3.97254348, Reconstruction Loss: 0.02631880, Isometric Loss: 0.50967449
# Epoch [100/100], Validation Loss: 4.05211544, Reconstruction Loss: 0.02567010, Isometric Loss: 0.52003545
# Model 1/4 with lambda_iso=7.743 trained and saved.
# Training model 2/4 with lambda_iso=7.743
# Epoch [100/100], Loss: 3.96090770, Reconstruction Loss: 0.02382429, Isometric Loss: 0.50849384
# Epoch [100/100], Validation Loss: 3.97033000, Reconstruction Loss: 0.03035696, Isometric Loss: 0.50886708
# Model 2/4 with lambda_iso=7.743 trained and saved.
# Training model 3/4 with lambda_iso=7.743
# Epoch [100/100], Loss: 3.97461247, Reconstruction Loss: 0.02964516, Isometric Loss: 0.50951213
# Epoch [100/100], Validation Loss: 4.16514683, Reconstruction Loss: 0.03123766, Isometric Loss: 0.53391492
# Model 3/4 with lambda_iso=7.743 trained and saved.
# Training model 4/4 with lambda_iso=7.743
# Epoch [100/100], Loss: 4.05495358, Reconstruction Loss: 0.03579742, Isometric Loss: 0.51909405
# Epoch [100/100], Validation Loss: 4.00183678, Reconstruction Loss: 0.04018345, Isometric Loss: 0.51166725
# Model 4/4 with lambda_iso=7.743 trained and saved.
# Training model 1/4 with lambda_iso=27.826
# Epoch [100/100], Loss: 13.86267090, Reconstruction Loss: 0.02995136, Isometric Loss: 0.49712217
# Epoch [100/100], Validation Loss: 14.37012672, Reconstruction Loss: 0.02897028, Isometric Loss: 0.51539445
# Model 1/4 with lambda_iso=27.826 trained and saved.
# Training model 2/4 with lambda_iso=27.826
# Epoch [100/100], Loss: 14.08694267, Reconstruction Loss: 0.04563788, Isometric Loss: 0.50461835
# Epoch [100/100], Validation Loss: 14.42018890, Reconstruction Loss: 0.04225683, Isometric Loss: 0.51671612
# Model 2/4 with lambda_iso=27.826 trained and saved.
# Training model 3/4 with lambda_iso=27.826
# Epoch [100/100], Loss: 14.86479092, Reconstruction Loss: 0.03316273, Isometric Loss: 0.53302109
# Epoch [100/100], Validation Loss: 13.23982620, Reconstruction Loss: 0.03141682, Isometric Loss: 0.47468561
# Model 3/4 with lambda_iso=27.826 trained and saved.
# Training model 4/4 with lambda_iso=27.826
# Epoch [100/100], Loss: 14.10380554, Reconstruction Loss: 0.01730755, Isometric Loss: 0.50624251
# Epoch [100/100], Validation Loss: 14.65942669, Reconstruction Loss: 0.01835056, Isometric Loss: 0.52617300
# Model 4/4 with lambda_iso=27.826 trained and saved.
# Training model 1/4 with lambda_iso=100.000
# Epoch [100/100], Loss: 51.08353806, Reconstruction Loss: 0.05274718, Isometric Loss: 0.51030791
# Epoch [100/100], Validation Loss: 50.75990677, Reconstruction Loss: 0.05220031, Isometric Loss: 0.50707710
# Model 1/4 with lambda_iso=100.000 trained and saved.
# Training model 2/4 with lambda_iso=100.000
# Epoch [100/100], Loss: 51.84770584, Reconstruction Loss: 0.09134775, Isometric Loss: 0.51756352
# Epoch [100/100], Validation Loss: 53.01924515, Reconstruction Loss: 0.08816652, Isometric Loss: 0.52931082
# Model 2/4 with lambda_iso=100.000 trained and saved.
# Training model 3/4 with lambda_iso=100.000
# Epoch [100/100], Loss: 52.62618637, Reconstruction Loss: 0.09004056, Isometric Loss: 0.52536142
# Epoch [100/100], Validation Loss: 49.59116745, Reconstruction Loss: 0.09354344, Isometric Loss: 0.49497628
# Model 3/4 with lambda_iso=100.000 trained and saved.
# Training model 4/4 with lambda_iso=100.000
# Epoch [100/100], Loss: 50.25970078, Reconstruction Loss: 0.06661021, Isometric Loss: 0.50193095
# Epoch [100/100], Validation Loss: 54.95288086, Reconstruction Loss: 0.06567433, Isometric Loss: 0.54887205
# Model 4/4 with lambda_iso=100.000 trained and saved.

# %%
plt.plot(lambda_isos, recon_errors, label='Reconstruction Error')
plt.plot(lambda_isos, regularization_errors, label='Regularization Error')
plt.xscale('log')
plt.xlabel('Lambda (log scale)')
plt.ylabel('Error')
plt.title('Reconstruction and Regularization Errors vs Lambda')
plt.legend()
plt.show()

# %%
# plot samples and latent space at different lambdas
fig, axs = plt.subplots(2, 10, figsize=(40, 8), subplot_kw=dict(projection='3d'))
for i, lambda_iso in enumerate(lambda_isos):
    model_path = f"models/scaled_isometric_autoencoder_s_curve/lambda_{lambda_iso:.3f}_model_{j+1}.pth"
    model = ScaledIsometricAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_iso=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    axs[0, i].scatter(encoded_data[:, 0].cpu(), encoded_data[:, 1].cpu(), c=val_labels, s=5)
    axs[0, i].set_title(f'Latent Space (λ={lambda_iso:.3f})')
    axs[0, i].view_init(90, 90, 0)
    # axs[0, i].set_xticks([])
    # axs[0, i].set_yticks([])
    #plot 3d data
    axs[1, i].scatter(reconstruction[:, 0].cpu(), reconstruction[:, 1].cpu(), reconstruction[:, 2].cpu(), c=val_labels, s=5)
    axs[1, i].set_title(f'Reconstruction (λ={lambda_iso:.3f})')

# %%
fig, axs = plt.subplots(2, 10, figsize=(40, 8), subplot_kw=dict(projection='3d'))
for i, lambda_iso in enumerate(lambda_isos):
    model_path = f"models/scaled_isometric_autoencoder_s_curve/lambda_{lambda_iso:.3f}_model_{j+1}.pth"
    model = ScaledIsometricAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_iso=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    trace_vals = np.zeros_like(encoded_data[:, 0].cpu())
    for j, z in enumerate(encoded_data):
        z = z.unsqueeze(0)  # Add batch dimension
        y = model.decode(z)  # Decode to get reconstruction
        y = y.squeeze(0)  # Remove batch dimension

        # Compute the Jacobian J of the decoder at point z
        J = torch.autograd.functional.jacobian(model.decode, z)[0,:,0,:]

        # Compute the trace of J^T J
        JtJ = J.T @ J
        trace_JtJ = torch.trace(JtJ)

        # Store the trace value as a label for the point
        trace_vals[j] = trace_JtJ.item() / JtJ.shape[0]  # Normalize by the number of dimensions

    p = axs[0, i].scatter(encoded_data[:, 0].cpu(), encoded_data[:, 1].cpu(), c=trace_vals, s=5)
    plt.colorbar(p)
    axs[0, i].set_title(f'Latent Space (λ={lambda_iso:.3f})')
    axs[0, i].view_init(90, 90, 0)
    # axs[0, i].set_xticks([])
    # axs[0, i].set_yticks([])
    #plot 3d data
    p = axs[1, i].scatter(reconstruction[:, 0].cpu(), reconstruction[:, 1].cpu(), reconstruction[:, 2].cpu(), c=trace_vals, s=5)
    plt.colorbar(p)
    axs[1, i].set_title(f'Reconstruction (λ={lambda_iso:.3f})')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 5
#       3 model_path = f"models/scaled_isometric_autoencoder_s_curve/lambda_{lambda_iso:.3f}_model_{j+1}.pth"
#       4 model = ScaledIsometricAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_iso=lambda_iso).to(device)
# ----> 5 model.load_state_dict(torch.load(model_path))
#       7 model.eval()
#       8 with torch.no_grad():
#
# File ~/anaconda3/envs/ML/lib/python3.13/site-packages/torch/serialization.py:1479, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1476 if "encoding" not in pickle_load_args.keys():
#    1477     pickle_load_args["encoding"] = "utf-8"
# -> 1479 with _open_file_like(f, "rb") as opened_file:
#    1480     if _is_zipfile(opened_file):
#    1481         # The zipfile reader is going to advance the current file position.
#    1482         # If we want to actually tail call to torch.jit.load, we need to
#    1483         # reset back to the original position.
#    1484         orig_position = opened_file.tell()
#
# File ~/anaconda3/envs/ML/lib/python3.13/site-packages/torch/serialization.py:759, in _open_file_like(name_or_buffer, mode)
#     757 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     758     if _is_path(name_or_buffer):
# --> 759         return _open_file(name_or_buffer, mode)
#     760     else:
#     761         if "w" in mode:
#
# File ~/anaconda3/envs/ML/lib/python3.13/site-packages/torch/serialization.py:740, in _open_file.__init__(self, name, mode)
#     739 def __init__(self, name: Union[str, os.PathLike[str]], mode: str) -> None:
# --> 740     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/scaled_isometric_autoencoder_s_curve/lambda_0.004_model_1000.pth'

# %%
def diagonality_loss(func, z):
    device = z.device
    losses = []
    for i, z in enumerate(encoded_data):
        z = z.unsqueeze(0)  # Add batch dimension
        y = func(z)  # Decode to get reconstruction
        y = y.squeeze(0)  # Remove batch dimension

        # Compute the Jacobian J of the decoder at point z
        J = torch.autograd.functional.jacobian(func, z)[0,:,0,:]
        JtJ = J.transpose(0, 1) @ J

        eye = torch.eye(JtJ.size(0), device=device)
        off_diag_mask = 1.0 - eye
        off_diag_elements = JtJ[off_diag_mask.bool()]
        loss_matrix = off_diag_elements ** 2

        losses.append(loss_matrix.mean().item())
    
    return np.mean(losses).item()

# %%
# measure isometry, scaled isometry, conformity, diagonality, (angle preservation, kl)
from metrics import isometry_loss, scaled_isometry_loss, conformality_loss

for i, lambda_iso in enumerate(lambda_isos):
    print(f"Evaluating model with lambda_iso={lambda_iso:.3f}")
    model_path = f"models/scaled_isometric_autoencoder_s_curve/lambda_{lambda_iso:.3f}_model_{j+1}.pth"
    model = ScaledIsometricAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_iso=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))

    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    isometry = isometry_loss(model.decoder, encoded_data, create_graph=False, augment=False)
    scaled_isometry = scaled_isometry_loss(model.decoder, encoded_data, create_graph=False, augment=False)
    conformality = conformality_loss(model.decoder, encoded_data)
    diagonality = diagonality_loss(model.decoder, encoded_data)
    print(f"Isometry Loss: {isometry.item()}")
    print(f"Scaled Isometry Loss: {scaled_isometry.item()}")
    print(f"Conformality Loss: {conformality.item()}")
    print(f"Diagonality Loss: {diagonality}")
    print("-" * 50)
# Out:
# Evaluating model with lambda_iso=0.001
# Isometry Loss: 0.030198201537132263
# Scaled Isometry Loss: 0.5588494539260864
# Conformality Loss: 45.173675537109375
# Diagonality Loss: 0.025357555102318588
# --------------------------------------------------
# Evaluating model with lambda_iso=0.004
# Isometry Loss: 0.020447447896003723
# Scaled Isometry Loss: 0.5480147004127502
# Conformality Loss: 34.43684387207031
# Diagonality Loss: 0.017241241908394104
# --------------------------------------------------
# Evaluating model with lambda_iso=0.013
# Isometry Loss: 0.011444643139839172
# Scaled Isometry Loss: 0.5289701819419861
# Conformality Loss: 42.44587707519531
# Diagonality Loss: 0.021127933980045942
# --------------------------------------------------
# Evaluating model with lambda_iso=0.046
# Isometry Loss: 0.01173069141805172
# Scaled Isometry Loss: 0.5163232684135437
# Conformality Loss: 37.75851821899414
# Diagonality Loss: 0.01960496960456461
# --------------------------------------------------
# Evaluating model with lambda_iso=0.167
# Isometry Loss: 0.013482864946126938
# Scaled Isometry Loss: 0.5414991974830627
# Conformality Loss: 40.136619567871094
# Diagonality Loss: 0.016745684792177574
# --------------------------------------------------
# Evaluating model with lambda_iso=0.599
# Isometry Loss: 0.008855864405632019
# Scaled Isometry Loss: 0.5574182868003845
# Conformality Loss: 32.34033966064453
# Diagonality Loss: 0.011223195931691908
# --------------------------------------------------
# Evaluating model with lambda_iso=2.154
# Isometry Loss: 0.005399723537266254
# Scaled Isometry Loss: 0.51624596118927
# Conformality Loss: 23.3328800201416
# Diagonality Loss: 0.011929851291728633
# --------------------------------------------------
# Evaluating model with lambda_iso=7.743
# Isometry Loss: 0.0012171597918495536
# Scaled Isometry Loss: 0.5315949320793152
# Conformality Loss: 4.269777774810791
# Diagonality Loss: 0.0020697833062805304
# --------------------------------------------------
# Evaluating model with lambda_iso=27.826
# Isometry Loss: 0.0011151047656312585
# Scaled Isometry Loss: 0.5121560096740723
# Conformality Loss: 4.545370101928711
# Diagonality Loss: 0.0027283764788981237
# --------------------------------------------------
# Evaluating model with lambda_iso=100.000
# Isometry Loss: 0.0010099124629050493
# Scaled Isometry Loss: 0.5198746919631958
# Conformality Loss: 3.8229522705078125
# Diagonality Loss: 0.0015768875755748039
# --------------------------------------------------
