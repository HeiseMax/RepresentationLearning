# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

from sklearn.datasets import make_moons, make_s_curve

from Autoencoders import ScaledIsometricAutoencoder
from helper import load_optimizer_and_scheduler, save_optimizer_and_scheduler
from data import make_half_sphere

random_state = 42
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super(Encoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, latent_dim)
        )
    
    def forward(self, x):
        return self.fc(x)

class Decoder(nn.Module):
    def __init__(self, latent_dim, output_dim):
        super(Decoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, output_dim)
        )
    
    def forward(self, z):
        return self.fc(z)

# %%
data, labels = make_half_sphere(n_samples=2000, noise=0.05, random_state=random_state)
data = torch.tensor(data, dtype=torch.float32).to(device)
val_data, val_labels = make_half_sphere(n_samples=1000, noise=0.05, random_state=random_state+1)
val_data = torch.tensor(val_data, dtype=torch.float32).to(device)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data[:, 0].cpu(), data[:, 1].cpu(), data[:, 2].cpu(), c=labels, s=5)
ax.set_title("Original Data in 3D")
ax.view_init(0, 180, 0)
plt.show()

# %%
# define model parameters
latent_dim = 2
input_dim = data.shape[1]
output_dim = data.shape[1]
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=False)

# %%
lambda_isos = np.logspace(-3, 2, 10)

# %%
num_epochs = 100
# train same model multiple times to average results
num_models = 4

recon_errors = []
regularization_errors = []


for i, lambda_iso in enumerate(lambda_isos):
    recon_error = 0
    regularization = 0
    for j in range(num_models):
        print(f"Training model {j+1}/{num_models} with lambda_iso={lambda_iso:.3f}")
        
        encoder = Encoder(input_dim, latent_dim).to(device)
        decoder = Decoder(latent_dim, output_dim).to(device)
        model = ScaledIsometricAutoencoder(encoder, decoder, lambda_iso=lambda_iso).to(device)

        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)

        # Train the model
        model.train_model(train_dataloader, val_dataloader, batch_size=batch_size, epochs=num_epochs,
                          optimizer=optimizer, scheduler=scheduler, verbose=True)

        # Save the model and optimizer state
        model_path = f"models/scaled_isometric_autoencoder_half_sphere/lambda_{lambda_iso:.3f}_model_{j+1}.pth"
        torch.save(model.state_dict(), model_path)
        print(f"Model {j+1}/{num_models} with lambda_iso={lambda_iso:.3f} trained and saved.")

        # evaluation
        model.eval()
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)
        
        recon_error += nn.MSELoss()(reconstruction, val_data).item()

        regularization += model.scaled_isometry_loss(model.decoder, encoded_data, create_graph=False, augment=False).item()
    
    recon_errors.append(recon_error/ num_models)
    regularization_errors.append(regularization/num_models)
# Out:
# Training model 1/4 with lambda_iso=0.001
# Epoch [100/100], Loss: 0.00148982, Reconstruction Loss: 0.00094852, Isometric Loss: 0.54129773
# Epoch [100/100], Validation Loss: 0.00173483, Reconstruction Loss: 0.00117304, Isometric Loss: 0.56178457
# Model 1/4 with lambda_iso=0.001 trained and saved.
# Training model 2/4 with lambda_iso=0.001
# Epoch [100/100], Loss: 0.00151399, Reconstruction Loss: 0.00095004, Isometric Loss: 0.56394589
# Epoch [100/100], Validation Loss: 0.00165384, Reconstruction Loss: 0.00111984, Isometric Loss: 0.53399861
# Model 2/4 with lambda_iso=0.001 trained and saved.
# Training model 3/4 with lambda_iso=0.001
# Epoch [100/100], Loss: 0.00153136, Reconstruction Loss: 0.00097000, Isometric Loss: 0.56136352
# Epoch [100/100], Validation Loss: 0.00170919, Reconstruction Loss: 0.00118465, Isometric Loss: 0.52454323
# Model 3/4 with lambda_iso=0.001 trained and saved.
# Training model 4/4 with lambda_iso=0.001
# Epoch [100/100], Loss: 0.00150862, Reconstruction Loss: 0.00096395, Isometric Loss: 0.54467309
# Epoch [100/100], Validation Loss: 0.00167530, Reconstruction Loss: 0.00117147, Isometric Loss: 0.50383019
# Model 4/4 with lambda_iso=0.001 trained and saved.
# Training model 1/4 with lambda_iso=0.004
# Epoch [100/100], Loss: 0.00298717, Reconstruction Loss: 0.00106987, Isometric Loss: 0.53350091
# Epoch [100/100], Validation Loss: 0.00332612, Reconstruction Loss: 0.00138502, Isometric Loss: 0.54012299
# Model 1/4 with lambda_iso=0.004 trained and saved.
# Training model 2/4 with lambda_iso=0.004
# Epoch [100/100], Loss: 0.00290869, Reconstruction Loss: 0.00096409, Isometric Loss: 0.54109508
# Epoch [100/100], Validation Loss: 0.00299207, Reconstruction Loss: 0.00116636, Isometric Loss: 0.50801516
# Model 2/4 with lambda_iso=0.004 trained and saved.
# Training model 3/4 with lambda_iso=0.004
# Epoch [100/100], Loss: 0.00302753, Reconstruction Loss: 0.00106739, Isometric Loss: 0.54541814
# Epoch [100/100], Validation Loss: 0.00299368, Reconstruction Loss: 0.00114517, Isometric Loss: 0.51435935
# Model 3/4 with lambda_iso=0.004 trained and saved.
# Training model 4/4 with lambda_iso=0.004
# Epoch [100/100], Loss: 0.00284541, Reconstruction Loss: 0.00101674, Isometric Loss: 0.50883633
# Epoch [100/100], Validation Loss: 0.00309528, Reconstruction Loss: 0.00117519, Isometric Loss: 0.53427833
# Model 4/4 with lambda_iso=0.004 trained and saved.
# Training model 1/4 with lambda_iso=0.013
# Epoch [100/100], Loss: 0.00780391, Reconstruction Loss: 0.00102742, Isometric Loss: 0.52467924
# Epoch [100/100], Validation Loss: 0.00839268, Reconstruction Loss: 0.00131412, Isometric Loss: 0.54806656
# Model 1/4 with lambda_iso=0.013 trained and saved.
# Training model 2/4 with lambda_iso=0.013
# Epoch [100/100], Loss: 0.00813020, Reconstruction Loss: 0.00109215, Isometric Loss: 0.54493046
# Epoch [100/100], Validation Loss: 0.00854382, Reconstruction Loss: 0.00120209, Isometric Loss: 0.56844425
# Model 2/4 with lambda_iso=0.013 trained and saved.
# Training model 3/4 with lambda_iso=0.013
# Epoch [100/100], Loss: 0.00765067, Reconstruction Loss: 0.00099950, Isometric Loss: 0.51497591
# Epoch [100/100], Validation Loss: 0.00863252, Reconstruction Loss: 0.00125099, Isometric Loss: 0.57152557
# Model 3/4 with lambda_iso=0.013 trained and saved.
# Training model 4/4 with lambda_iso=0.013
# Epoch [100/100], Loss: 0.00757528, Reconstruction Loss: 0.00100225, Isometric Loss: 0.50892580
# Epoch [100/100], Validation Loss: 0.00803606, Reconstruction Loss: 0.00119159, Isometric Loss: 0.52994227
# Model 4/4 with lambda_iso=0.013 trained and saved.
# Training model 1/4 with lambda_iso=0.046
# Epoch [100/100], Loss: 0.02630519, Reconstruction Loss: 0.00133496, Isometric Loss: 0.53796732
# Epoch [100/100], Validation Loss: 0.02747756, Reconstruction Loss: 0.00144510, Isometric Loss: 0.56085235
# Model 1/4 with lambda_iso=0.046 trained and saved.
# Training model 2/4 with lambda_iso=0.046
# Epoch [100/100], Loss: 0.02468104, Reconstruction Loss: 0.00121800, Isometric Loss: 0.50549591
# Epoch [100/100], Validation Loss: 0.02630059, Reconstruction Loss: 0.00145637, Isometric Loss: 0.53525263
# Model 2/4 with lambda_iso=0.046 trained and saved.
# Training model 3/4 with lambda_iso=0.046
# Epoch [100/100], Loss: 0.02419184, Reconstruction Loss: 0.00110934, Isometric Loss: 0.49729735
# Epoch [100/100], Validation Loss: 0.02693029, Reconstruction Loss: 0.00142921, Isometric Loss: 0.54940408
# Model 3/4 with lambda_iso=0.046 trained and saved.
# Training model 4/4 with lambda_iso=0.046
# Epoch [100/100], Loss: 0.02600277, Reconstruction Loss: 0.00126409, Isometric Loss: 0.53297865
# Epoch [100/100], Validation Loss: 0.02651223, Reconstruction Loss: 0.00147409, Isometric Loss: 0.53943026
# Model 4/4 with lambda_iso=0.046 trained and saved.
# Training model 1/4 with lambda_iso=0.167
# Epoch [100/100], Loss: 0.08761333, Reconstruction Loss: 0.00240821, Isometric Loss: 0.51079118
# Epoch [100/100], Validation Loss: 0.08602862, Reconstruction Loss: 0.00268508, Isometric Loss: 0.49963140
# Model 1/4 with lambda_iso=0.167 trained and saved.
# Training model 2/4 with lambda_iso=0.167
# Epoch [100/100], Loss: 0.08686248, Reconstruction Loss: 0.00222953, Isometric Loss: 0.50736123
# Epoch [100/100], Validation Loss: 0.08718146, Reconstruction Loss: 0.00257246, Isometric Loss: 0.50721771
# Model 2/4 with lambda_iso=0.167 trained and saved.
# Training model 3/4 with lambda_iso=0.167
# Epoch [100/100], Loss: 0.09598832, Reconstruction Loss: 0.00258630, Isometric Loss: 0.55993044
# Epoch [100/100], Validation Loss: 0.09694536, Reconstruction Loss: 0.00269084, Isometric Loss: 0.56504101
# Model 3/4 with lambda_iso=0.167 trained and saved.
# Training model 4/4 with lambda_iso=0.167
# Epoch [100/100], Loss: 0.09184271, Reconstruction Loss: 0.00258728, Isometric Loss: 0.53507221
# Epoch [100/100], Validation Loss: 0.09006171, Reconstruction Loss: 0.00279979, Isometric Loss: 0.52312148
# Model 4/4 with lambda_iso=0.167 trained and saved.
# Training model 1/4 with lambda_iso=0.599
# Epoch [100/100], Loss: 0.29808062, Reconstruction Loss: 0.00495748, Isometric Loss: 0.48895890
# Epoch [100/100], Validation Loss: 0.33489460, Reconstruction Loss: 0.00549535, Isometric Loss: 0.54947108
# Model 1/4 with lambda_iso=0.599 trained and saved.
# Training model 2/4 with lambda_iso=0.599
# Epoch [100/100], Loss: 0.33737803, Reconstruction Loss: 0.00576170, Isometric Loss: 0.55316931
# Epoch [100/100], Validation Loss: 0.29360101, Reconstruction Loss: 0.00734292, Isometric Loss: 0.47750726
# Model 2/4 with lambda_iso=0.599 trained and saved.
# Training model 3/4 with lambda_iso=0.599
# Epoch [100/100], Loss: 0.31184983, Reconstruction Loss: 0.00585432, Isometric Loss: 0.51043123
# Epoch [100/100], Validation Loss: 0.31178424, Reconstruction Loss: 0.00722634, Isometric Loss: 0.50803316
# Model 3/4 with lambda_iso=0.599 trained and saved.
# Training model 4/4 with lambda_iso=0.599
# Epoch [100/100], Loss: 0.30799058, Reconstruction Loss: 0.00546204, Isometric Loss: 0.50464797
# Epoch [100/100], Validation Loss: 0.33295369, Reconstruction Loss: 0.00659984, Isometric Loss: 0.54439098
# Model 4/4 with lambda_iso=0.599 trained and saved.
# Training model 1/4 with lambda_iso=2.154
# Epoch [100/100], Loss: 1.13298512, Reconstruction Loss: 0.00799251, Isometric Loss: 0.52217531
# Epoch [100/100], Validation Loss: 1.13384056, Reconstruction Loss: 0.00800410, Isometric Loss: 0.52256697
# Model 1/4 with lambda_iso=2.154 trained and saved.
# Training model 2/4 with lambda_iso=2.154
# Epoch [100/100], Loss: 1.07895970, Reconstruction Loss: 0.00996561, Isometric Loss: 0.49618310
# Epoch [100/100], Validation Loss: 1.02504265, Reconstruction Loss: 0.00942408, Isometric Loss: 0.47140840
# Model 2/4 with lambda_iso=2.154 trained and saved.
# Training model 3/4 with lambda_iso=2.154
# Epoch [100/100], Loss: 1.13821983, Reconstruction Loss: 0.00901016, Isometric Loss: 0.52413273
# Epoch [100/100], Validation Loss: 1.07749820, Reconstruction Loss: 0.00954378, Isometric Loss: 0.49570057
# Model 3/4 with lambda_iso=2.154 trained and saved.
# Training model 4/4 with lambda_iso=2.154
# Epoch [100/100], Loss: 1.07170868, Reconstruction Loss: 0.00852871, Isometric Loss: 0.49348444
# Epoch [100/100], Validation Loss: 1.08982646, Reconstruction Loss: 0.00967167, Isometric Loss: 0.50136346
# Model 4/4 with lambda_iso=2.154 trained and saved.
# Training model 1/4 with lambda_iso=7.743
# Epoch [100/100], Loss: 3.90994000, Reconstruction Loss: 0.01461254, Isometric Loss: 0.50310093
# Epoch [100/100], Validation Loss: 3.88210845, Reconstruction Loss: 0.01701658, Isometric Loss: 0.49919581
# Model 1/4 with lambda_iso=7.743 trained and saved.
# Training model 2/4 with lambda_iso=7.743
# Epoch [100/100], Loss: 4.14040184, Reconstruction Loss: 0.01388837, Isometric Loss: 0.53295964
# Epoch [100/100], Validation Loss: 3.77869368, Reconstruction Loss: 0.01710828, Isometric Loss: 0.48582745
# Model 2/4 with lambda_iso=7.743 trained and saved.
# Training model 3/4 with lambda_iso=7.743
# Epoch [100/100], Loss: 3.76943350, Reconstruction Loss: 0.01661263, Isometric Loss: 0.48469549
# Epoch [100/100], Validation Loss: 4.06788731, Reconstruction Loss: 0.01883585, Isometric Loss: 0.52295506
# Model 3/4 with lambda_iso=7.743 trained and saved.
# Training model 4/4 with lambda_iso=7.743
# Epoch [100/100], Loss: 3.74863410, Reconstruction Loss: 0.00963027, Isometric Loss: 0.48291090
# Epoch [100/100], Validation Loss: 4.07687569, Reconstruction Loss: 0.01093463, Isometric Loss: 0.52513647
# Model 4/4 with lambda_iso=7.743 trained and saved.
# Training model 1/4 with lambda_iso=27.826
# Epoch [100/100], Loss: 13.57913399, Reconstruction Loss: 0.01178080, Isometric Loss: 0.48758543
# Epoch [100/100], Validation Loss: 14.54094315, Reconstruction Loss: 0.01340993, Isometric Loss: 0.52209246
# Model 1/4 with lambda_iso=27.826 trained and saved.
# Training model 2/4 with lambda_iso=27.826
# Epoch [100/100], Loss: 14.60536671, Reconstruction Loss: 0.04592429, Isometric Loss: 0.52323925
# Epoch [100/100], Validation Loss: 14.71581554, Reconstruction Loss: 0.04823413, Isometric Loss: 0.52712554
# Model 2/4 with lambda_iso=27.826 trained and saved.
# Training model 3/4 with lambda_iso=27.826
# Epoch [100/100], Loss: 14.40085602, Reconstruction Loss: 0.01262971, Isometric Loss: 0.51708603
# Epoch [100/100], Validation Loss: 14.32303524, Reconstruction Loss: 0.01333498, Isometric Loss: 0.51426393
# Model 3/4 with lambda_iso=27.826 trained and saved.
# Training model 4/4 with lambda_iso=27.826
# Epoch [100/100], Loss: 14.77573109, Reconstruction Loss: 0.04103667, Isometric Loss: 0.52953750
# Epoch [100/100], Validation Loss: 15.48322392, Reconstruction Loss: 0.04442729, Isometric Loss: 0.55484158
# Model 4/4 with lambda_iso=27.826 trained and saved.
# Training model 1/4 with lambda_iso=100.000
# Epoch [100/100], Loss: 49.37885284, Reconstruction Loss: 0.04253535, Isometric Loss: 0.49336320
# Epoch [100/100], Validation Loss: 51.68398285, Reconstruction Loss: 0.04463637, Isometric Loss: 0.51639354
# Model 1/4 with lambda_iso=100.000 trained and saved.
# Training model 2/4 with lambda_iso=100.000
# Epoch [100/100], Loss: 50.26548767, Reconstruction Loss: 0.03896773, Isometric Loss: 0.50226521
# Epoch [100/100], Validation Loss: 52.92973328, Reconstruction Loss: 0.04022955, Isometric Loss: 0.52889502
# Model 2/4 with lambda_iso=100.000 trained and saved.
# Training model 3/4 with lambda_iso=100.000
# Epoch [100/100], Loss: 52.64871597, Reconstruction Loss: 0.04055058, Isometric Loss: 0.52608168
# Epoch [100/100], Validation Loss: 50.87210464, Reconstruction Loss: 0.05200838, Isometric Loss: 0.50820094
# Model 3/4 with lambda_iso=100.000 trained and saved.
# Training model 4/4 with lambda_iso=100.000
# Epoch [100/100], Loss: 50.40824509, Reconstruction Loss: 0.03834664, Isometric Loss: 0.50369895
# Epoch [100/100], Validation Loss: 49.27696228, Reconstruction Loss: 0.03903474, Isometric Loss: 0.49237925
# Model 4/4 with lambda_iso=100.000 trained and saved.

# %%
plt.plot(lambda_isos, recon_errors, label='Reconstruction Error')
plt.plot(lambda_isos, regularization_errors, label='Regularization Error')
plt.xscale('log')
plt.xlabel('Lambda (log scale)')
plt.ylabel('Error')
plt.title('Reconstruction and Regularization Errors vs Lambda')
plt.legend()
plt.show()

# %%
plt.plot(lambda_isos, recon_errors, label='Reconstruction Error')
# plt.plot(lambda_isos, regularization_errors, label='Regularization Error')
plt.xscale('log')
plt.yscale('log')
plt.ylim(0, 0.06)
plt.xlabel('Lambda (log scale)')
plt.ylabel('Error')
plt.title('Reconstruction and Regularization Errors vs Lambda')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_9494/1270011613.py:5: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0, 0.06)

# %%
# plot samples and latent space at different lambdas
fig, axs = plt.subplots(2, 10, figsize=(40, 8), subplot_kw=dict(projection='3d'))
for i, lambda_iso in enumerate(lambda_isos):
    model_path = f"models/scaled_isometric_autoencoder_half_sphere/lambda_{lambda_iso:.3f}_model_1.pth"
    model = ScaledIsometricAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_iso=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    axs[0, i].scatter(encoded_data[:, 0].cpu(), encoded_data[:, 1].cpu(), c=val_labels, s=5)
    axs[0, i].set_title(f'Latent Space (λ={lambda_iso:.3f})')
    axs[0, i].view_init(90, 90, 0)
    # axs[0, i].set_xticks([])
    # axs[0, i].set_yticks([])
    #plot 3d data
    axs[1, i].scatter(reconstruction[:, 0].cpu(), reconstruction[:, 1].cpu(), reconstruction[:, 2].cpu(), c=val_labels, s=5)
    axs[1, i].set_title(f'Reconstruction (λ={lambda_iso:.3f})')

# %%
fig, axs = plt.subplots(2, 10, figsize=(40, 8), subplot_kw=dict(projection='3d'))
for i, lambda_iso in enumerate(lambda_isos):
    model_path = f"models/scaled_isometric_autoencoder_half_sphere/lambda_{lambda_iso:.3f}_model_1.pth"
    model = ScaledIsometricAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_iso=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    trace_vals = np.zeros_like(encoded_data[:, 0].cpu())
    for j, z in enumerate(encoded_data):
        z = z.unsqueeze(0)  # Add batch dimension
        y = model.decode(z)  # Decode to get reconstruction
        y = y.squeeze(0)  # Remove batch dimension

        # Compute the Jacobian J of the decoder at point z
        J = torch.autograd.functional.jacobian(model.decode, z)[0,:,0,:]

        # Compute the trace of J^T J
        JtJ = J.T @ J
        trace_JtJ = torch.trace(JtJ)

        # Store the trace value as a label for the point
        trace_vals[j] = trace_JtJ.item() / JtJ.shape[0]  # Normalize by the number of dimensions

    p = axs[0, i].scatter(encoded_data[:, 0].cpu(), encoded_data[:, 1].cpu(), c=trace_vals, s=5)
    plt.colorbar(p)
    axs[0, i].set_title(f'Latent Space (λ={lambda_iso:.3f})')
    axs[0, i].view_init(90, 90, 0)
    # axs[0, i].set_xticks([])
    # axs[0, i].set_yticks([])
    #plot 3d data
    p = axs[1, i].scatter(reconstruction[:, 0].cpu(), reconstruction[:, 1].cpu(), reconstruction[:, 2].cpu(), c=trace_vals, s=5)
    plt.colorbar(p)
    axs[1, i].set_title(f'Reconstruction (λ={lambda_iso:.3f})')

# %%
def diagonality_loss(func, z):
    device = z.device
    losses = []
    for i, z in enumerate(encoded_data):
        z = z.unsqueeze(0)  # Add batch dimension
        y = func(z)  # Decode to get reconstruction
        y = y.squeeze(0)  # Remove batch dimension

        # Compute the Jacobian J of the decoder at point z
        J = torch.autograd.functional.jacobian(func, z)[0,:,0,:]
        JtJ = J.transpose(0, 1) @ J

        eye = torch.eye(JtJ.size(0), device=device)
        off_diag_mask = 1.0 - eye
        off_diag_elements = JtJ[off_diag_mask.bool()]
        loss_matrix = off_diag_elements ** 2

        losses.append(loss_matrix.mean().item())
    
    return np.mean(losses).item()

# %%
# measure isometry, scaled isometry, conformity, diagonality, (angle preservation, kl)
from metrics import isometry_loss, scaled_isometry_loss, conformality_loss

for i, lambda_iso in enumerate(lambda_isos):
    print(f"Evaluating model with lambda_iso={lambda_iso:.3f}")
    model_path = f"models/scaled_isometric_autoencoder_half_sphere/lambda_{lambda_iso:.3f}_model_3.pth"
    model = ScaledIsometricAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_iso=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))

    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    isometry = isometry_loss(model.decoder, encoded_data, create_graph=False, augment=False)
    scaled_isometry = scaled_isometry_loss(model.decoder, encoded_data, create_graph=False, augment=False)
    conformality = conformality_loss(model.decoder, encoded_data)
    diagonality = diagonality_loss(model.decoder, encoded_data)
    print(f"Isometry Loss: {isometry.item()}")
    print(f"Scaled Isometry Loss: {scaled_isometry.item()}")
    print(f"Conformality Loss: {conformality.item()}")
    print(f"Diagonality Loss: {diagonality}")
    print("-" * 50)
# Out:
# Evaluating model with lambda_iso=0.001
# Isometry Loss: 0.021242255344986916
# Scaled Isometry Loss: 0.5355237722396851
# Conformality Loss: 21.83152198791504
# Diagonality Loss: 0.015747754436796484
# --------------------------------------------------
# Evaluating model with lambda_iso=0.004
# Isometry Loss: 0.020266054198145866
# Scaled Isometry Loss: 0.5341371893882751
# Conformality Loss: 18.64196014404297
# Diagonality Loss: 0.009323501959061972
# --------------------------------------------------
# Evaluating model with lambda_iso=0.013
# Isometry Loss: 0.027098678052425385
# Scaled Isometry Loss: 0.5351660847663879
# Conformality Loss: 19.87563133239746
# Diagonality Loss: 0.010564383296101303
# --------------------------------------------------
# Evaluating model with lambda_iso=0.046
# Isometry Loss: 0.08003494888544083
# Scaled Isometry Loss: 0.5564096570014954
# Conformality Loss: 7.275337219238281
# Diagonality Loss: 0.0042560888022778595
# --------------------------------------------------
# Evaluating model with lambda_iso=0.167
# Isometry Loss: 0.30487531423568726
# Scaled Isometry Loss: 0.5185779929161072
# Conformality Loss: 1.3467744588851929
# Diagonality Loss: 0.0005788069900046808
# --------------------------------------------------
# Evaluating model with lambda_iso=0.599
# Isometry Loss: 0.23161450028419495
# Scaled Isometry Loss: 0.5214914679527283
# Conformality Loss: 1.1731780767440796
# Diagonality Loss: 0.0004997370805171808
# --------------------------------------------------
# Evaluating model with lambda_iso=2.154
# Isometry Loss: 0.17796780169010162
# Scaled Isometry Loss: 0.4978429973125458
# Conformality Loss: 0.8196858763694763
# Diagonality Loss: 0.0004029358635390688
# --------------------------------------------------
# Evaluating model with lambda_iso=7.743
# Isometry Loss: 0.11911866068840027
# Scaled Isometry Loss: 0.5250871181488037
# Conformality Loss: 0.7276313304901123
# Diagonality Loss: 0.0004631444316420278
# --------------------------------------------------
# Evaluating model with lambda_iso=27.826
# Isometry Loss: 0.0914449691772461
# Scaled Isometry Loss: 0.4980279803276062
# Conformality Loss: 0.35422593355178833
# Diagonality Loss: 0.00022292260494387127
# --------------------------------------------------
# Evaluating model with lambda_iso=100.000
# Isometry Loss: 0.18873177468776703
# Scaled Isometry Loss: 0.5205245614051819
# Conformality Loss: 0.10862705111503601
# Diagonality Loss: 4.3207153074684e-05
# --------------------------------------------------
